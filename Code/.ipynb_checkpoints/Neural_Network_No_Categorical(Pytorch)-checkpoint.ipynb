# %% [markdown]
# # Neural Network for CLA Project

# %% [markdown]
# ## Import statements

# %%
from sklearn import preprocessing
from sklearn import model_selection
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as utils
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import errno
import os
import sys
import Constants
import copy

# %% [markdown]
# ## Hyperparameters

# %%
# yearly summer dataset parameters
# data processing
# sample_bias = 0     # adjust the difference in the number of the two types of samples (no algae vs algae)
# test_size = 0.2
# batch_size = 96    # batch size for the DataLoaders. previously was 100

# NN model
# num_features = 21
# input_size = num_features     # size of input layer
# multiplier = 100         # multiplied by num_features to determine the size of each hidden layer. previously was 100
# hidden_size = multiplier * input_size
# output_size = 1
# learning_rate = 0.01         # learning rate of optimizer. previously was 0.01
# num_epochs = 100                # number of epochs

# all data summer data set hyperparameters
# data processing
sample_bias = 0     # adjust the difference in the number of the two types of samples (no algae vs algae)
test_size = 0.2
batch_size = 96    # batch size for the DataLoaders. previously was 100

# NN model
num_features = 15
input_size = num_features     # size of input layer
multiplier = 100         # multiplied by num_features to determine the size of each hidden layer. previously was 100
hidden_size = multiplier * input_size
output_size = 1
learning_rate = 0.01         # learning rate of optimizer. previously was 0.01
num_epochs = 10                # number of epochs

# %% [markdown]
# ## Read in data

# %%
np.set_printoptions(threshold=np.inf)  # prints a full matrix rather than an abbreviated matrix

# define data and destination paths
dest_path = "/Users/Alliot/Documents/CLA-Project/Data/all-data-no-na/neural-network/"
data_path = "/Users/Alliot/Documents/CLA-Project/Data/data-sets/"
data_set = "all_data_summer"

# load data sets
X = np.load(data_path + data_set + "_no_categorical.npy")
y = np.load(data_path + data_set + "_labels.npy")

# manipulate data set. labels are converted to 0, +1 for binary classification; samples are removed uniformly 
# from the data set so that the disproportionately large number of negative samples (no algae) does 
# not bias the model.

num_alg = 0  # count the number of algae instances
num_no_alg = 0  # count the number of no algae instances

# Convert labels to binary: -1 for no algae and 1 for algae
for i in range(0, len(y)):
    if y[i] == 0:
        num_no_alg += 1
    if y[i] == 1 or y[i] == 2:
        y[i] = 1
        num_alg += 1

# oversample the data set by randomly adding occurences of algae until the difference between the number of algae
# samples and no algae samples equals sample_bias (defined below)
idx = 0
sample_bias = 0
length_y = len(y)
while num_alg != (num_no_alg + sample_bias):
    # circle through the data sets until the difference of num_no_alg and num_alg equals
    # the value specified by sample_bias
    if idx == (length_y - 1):
        idx = 0

    if y[idx] == 1:
        if np.random.rand() >= 0.5:  # add this sample with some probability
            y = np.append(y, y[idx])
            X = np.append(X, np.reshape(X[idx, :], newshape=(1, num_features)), axis=0)
            num_alg += 1
        else:
            idx += 1
    else:
        idx += 1

# %% [markdown]
# ### Process and split data set

# %%
# standardize data: remove the mean and variance in each sample
num_splits = 2   # do not change
sss = model_selection.StratifiedShuffleSplit(n_splits=num_splits, test_size=test_size)

idx, _ = sss.split(X, y);
train_idx = idx[0]
test_idx = idx[1]
X_train, X_test = X[train_idx], X[test_idx]
y_train, y_test = y[train_idx], y[test_idx]

X_train = preprocessing.scale(X_train, axis=1, with_mean=True, with_std=True)
X_test = preprocessing.scale(X_test, axis=1, with_mean=True, with_std=True)

# convert numpy arrays to pytorch tensors
train_set_size = X_train.shape
test_set_size = X_test.shape
X_train, X_test = torch.from_numpy(X_train), torch.from_numpy(X_test)
y_train, y_test = torch.from_numpy(y_train), torch.from_numpy(y_test)

# convert pytorch tensors to pytorch TensorDataset
train_set = utils.TensorDataset(X_train, y_train)
test_set = utils.TensorDataset(X_test, y_test)

# create DataLoaders
train_loader = utils.DataLoader(train_set, batch_size=batch_size, shuffle=True)
test_loader = utils.DataLoader(test_set, batch_size=test_set_size[0], shuffle=True)

# %% [markdown]
# ## Define neural network model

# %%
class CLANet(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(CLANet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.tanh2 = nn.Tanh()
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(hidden_size, hidden_size)
        self.tanh4 = nn.Tanh()
        self.fc5 = nn.Linear(hidden_size, hidden_size)
        self.relu5 = nn.ReLU()
        self.fc6 = nn.Linear(hidden_size, output_size)     # previously, this was output_size
#         self.tanh6 = nn.Tanh()                             # previously, this was the line which was commented out
#         self.fc7 = nn.Linear(hidden_size, output_size)
#         self.relu7 = nn.ReLU()
#         self.fc8 = nn.Linear(hidden_size, hidden_size)
#         self.relu8 = nn.ReLU()
#         self.fc9 = nn.Linear(hidden_size, output_size)
#         self.relu9 = nn.ReLU()
#         self.fc10 = nn.Linear(hidden_size, hidden_size)
#         self.relu10 = nn.ReLU()
#         self.fc11 = nn.Linear(hidden_size, hidden_size)
#         self.relu11 = nn.ReLU()
#         self.fc12 = nn.Linear(hidden_size, output_size)
        self.sig1 = nn.Sigmoid()
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu1(out)
        out = self.fc2(out)
        out = self.tanh2(out)
        out = self.fc3(out)
        out = self.relu3(out)
        out = self.fc4(out)
        out = self.tanh4(out)
        out = self.fc5(out)
        out = self.relu5(out)
        out = self.fc6(out)
#         out = self.tanh6(out)
#         out = self.fc7(out)
#         out = self.relu7(out)
#         out = self.fc8(out)
#         out = self.relu8(out)
#         out = self.fc9(out)
#         out = self.relu9(out)
#         out = self.fc10(out)
#         out = self.relu10(out)
#         out = self.fc11(out)
#         out = self.relu11(out)
#         out = self.fc12(out)
        out = self.sig1(out)
        return out

# %% [markdown]
# ### Instantiate the neural network

# %%
model = CLANet(input_size, hidden_size, output_size)
criterion = nn.BCELoss()

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, nesterov=True, momentum=1, dampening=0)
# optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-8)
model.double();     # cast model parameters to double
use_previous_best_error = False

# %% [markdown]
# ## Train the neural network

# %%
model.train()     # training mode
if not use_previous_best_error:
    avg_error = 0

avg_error_vec = []
best_avg_error = 1

for epoch in range(num_epochs):
    print("Epoch: %d/%d" % (epoch+1, num_epochs))

    for i, (samples, labels) in enumerate(train_loader):        
        samples = Variable(samples)
        labels = Variable(labels)
        output = model(samples)                # forward pass
        output = torch.flatten(output)         # resize predicted labels
        labels = labels.type(torch.DoubleTensor)
        
        loss = criterion(output, labels)  # calculate loss
        optimizer.zero_grad()     # clear gradient
        loss.backward()           # calculate gradients
        optimizer.step()          # update weights
                
        # calculate and print error
        out = output

        for j in range(0, out.size()[0]):
            if out[j] < 0.5:
                out[j] = 0
            else:
                out[j] = 1
        error = 1 - torch.sum(output == labels).item() / labels.size()[0]
        avg_error += error
        print("  Iteration: %d/%d, Loss: %g, Error: %0.4f" % 
              (i+1, np.ceil(X_train.size()[0] / batch_size).astype(int), loss.item(), error))
    
    avg_error = avg_error / np.ceil(X_train.size()[0] / batch_size)
    avg_error_vec.append(avg_error)
    print("Average Error for this Epoch: %0.4f" % avg_error)

    if avg_error < best_avg_error:
        print("found a better model!")
        best_avg_error = avg_error
        best_model = copy.deepcopy(model)
        use_previous_best_error = True
    
    avg_error = 0
# Out:
# Epoch: 1/10
#   Iteration: 1/57, Loss: 0.553336, Error: 0.2292
#   Iteration: 2/57, Loss: 0.636745, Error: 0.3750
#   Iteration: 3/57, Loss: 0.590271, Error: 0.3021
#   Iteration: 4/57, Loss: 0.563156, Error: 0.2500
#   Iteration: 5/57, Loss: 0.566816, Error: 0.2292
#   Iteration: 6/57, Loss: 0.539967, Error: 0.2083
#   Iteration: 7/57, Loss: 0.614266, Error: 0.2917
#   Iteration: 8/57, Loss: 0.598806, Error: 0.2604
#   Iteration: 9/57, Loss: 0.623271, Error: 0.3125
#   Iteration: 10/57, Loss: 0.555834, Error: 0.2500
#   Iteration: 11/57, Loss: 0.652386, Error: 0.3750
#   Iteration: 12/57, Loss: 0.684261, Error: 0.4062
#   Iteration: 13/57, Loss: 0.62751, Error: 0.3125
#   Iteration: 14/57, Loss: 0.627061, Error: 0.3333
#   Iteration: 15/57, Loss: 0.575993, Error: 0.2812
#   Iteration: 16/57, Loss: 0.652059, Error: 0.3542
#   Iteration: 17/57, Loss: 0.661342, Error: 0.3750
#   Iteration: 18/57, Loss: 0.587471, Error: 0.2708
#   Iteration: 19/57, Loss: 0.678883, Error: 0.4271
#   Iteration: 20/57, Loss: 0.631889, Error: 0.3750
#   Iteration: 21/57, Loss: 0.66603, Error: 0.3854
#   Iteration: 22/57, Loss: 0.563434, Error: 0.2708
#   Iteration: 23/57, Loss: 0.606457, Error: 0.3125
#   Iteration: 24/57, Loss: 0.61738, Error: 0.3229
#   Iteration: 25/57, Loss: 0.58615, Error: 0.2812
#   Iteration: 26/57, Loss: 0.607942, Error: 0.2917
#   Iteration: 27/57, Loss: 0.595027, Error: 0.3021
#   Iteration: 28/57, Loss: 0.618955, Error: 0.3542
#   Iteration: 29/57, Loss: 0.662594, Error: 0.3229
#   Iteration: 30/57, Loss: 0.616074, Error: 0.3125
#   Iteration: 31/57, Loss: 0.614098, Error: 0.3333
#   Iteration: 32/57, Loss: 0.602883, Error: 0.3021
#   Iteration: 33/57, Loss: 0.635451, Error: 0.3125
#   Iteration: 34/57, Loss: 0.649052, Error: 0.3646
#   Iteration: 35/57, Loss: 0.638662, Error: 0.3750
#   Iteration: 36/57, Loss: 0.616525, Error: 0.3125
#   Iteration: 37/57, Loss: 0.612511, Error: 0.2604
#   Iteration: 38/57, Loss: 0.648099, Error: 0.3750
#   Iteration: 39/57, Loss: 0.646031, Error: 0.3646
#   Iteration: 40/57, Loss: 0.65411, Error: 0.3542
#   Iteration: 41/57, Loss: 0.667226, Error: 0.3958
#   Iteration: 42/57, Loss: 0.576367, Error: 0.2812
#   Iteration: 43/57, Loss: 0.626142, Error: 0.3542
#   Iteration: 44/57, Loss: 0.64611, Error: 0.3646
#   Iteration: 45/57, Loss: 0.611542, Error: 0.3229
#   Iteration: 46/57, Loss: 0.627313, Error: 0.3333
#   Iteration: 47/57, Loss: 0.626205, Error: 0.3021
#   Iteration: 48/57, Loss: 0.599197, Error: 0.2917
#   Iteration: 49/57, Loss: 0.608138, Error: 0.3438
#   Iteration: 50/57, Loss: 0.542065, Error: 0.2500
#   Iteration: 51/57, Loss: 0.623397, Error: 0.3229
#   Iteration: 52/57, Loss: 0.644776, Error: 0.3438
#   Iteration: 53/57, Loss: 0.645035, Error: 0.3750
#   Iteration: 54/57, Loss: 0.610462, Error: 0.3333
#   Iteration: 55/57, Loss: 0.562611, Error: 0.2917
#   Iteration: 56/57, Loss: 0.594934, Error: 0.2708
#   Iteration: 57/57, Loss: 0.604503, Error: 0.3333
# Average Error for this Epoch: 0.3200
# found a better model!
# Epoch: 2/10
#   Iteration: 1/57, Loss: 0.594771, Error: 0.3021
#   Iteration: 2/57, Loss: 0.561798, Error: 0.2396
#   Iteration: 3/57, Loss: 0.613128, Error: 0.3438
#   Iteration: 4/57, Loss: 0.614879, Error: 0.3646
#   Iteration: 5/57, Loss: 0.61813, Error: 0.3021
#   Iteration: 6/57, Loss: 0.63414, Error: 0.2917
#   Iteration: 7/57, Loss: 0.588767, Error: 0.2917
#   Iteration: 8/57, Loss: 0.596614, Error: 0.2812
#   Iteration: 9/57, Loss: 0.588474, Error: 0.2604
#   Iteration: 10/57, Loss: 0.612157, Error: 0.3229
#   Iteration: 11/57, Loss: 0.6092, Error: 0.3229
#   Iteration: 12/57, Loss: 0.601348, Error: 0.3229
#   Iteration: 13/57, Loss: 0.607833, Error: 0.3021
#   Iteration: 14/57, Loss: 0.653444, Error: 0.3646
#   Iteration: 15/57, Loss: 0.592657, Error: 0.2500
#   Iteration: 16/57, Loss: 0.61731, Error: 0.3542
#   Iteration: 17/57, Loss: 0.622174, Error: 0.3438
#   Iteration: 18/57, Loss: 0.602809, Error: 0.3646
#   Iteration: 19/57, Loss: 0.622041, Error: 0.3542
#   Iteration: 20/57, Loss: 0.652065, Error: 0.3750
#   Iteration: 21/57, Loss: 0.602308, Error: 0.2812
#   Iteration: 22/57, Loss: 0.621021, Error: 0.3229
#   Iteration: 23/57, Loss: 0.598356, Error: 0.2708
#   Iteration: 24/57, Loss: 0.611738, Error: 0.2812
#   Iteration: 25/57, Loss: 0.655217, Error: 0.3542
#   Iteration: 26/57, Loss: 0.577893, Error: 0.3021
#   Iteration: 27/57, Loss: 0.581655, Error: 0.2604
#   Iteration: 28/57, Loss: 0.571245, Error: 0.3021
#   Iteration: 29/57, Loss: 0.687649, Error: 0.4062
#   Iteration: 30/57, Loss: 0.552719, Error: 0.2604
#   Iteration: 31/57, Loss: 0.585956, Error: 0.2708
#   Iteration: 32/57, Loss: 0.620338, Error: 0.3438
#   Iteration: 33/57, Loss: 0.580891, Error: 0.2917
#   Iteration: 34/57, Loss: 0.670093, Error: 0.3750
#   Iteration: 35/57, Loss: 0.683571, Error: 0.3854
#   Iteration: 36/57, Loss: 0.587385, Error: 0.2812
#   Iteration: 37/57, Loss: 0.587955, Error: 0.2917
#   Iteration: 38/57, Loss: 0.633034, Error: 0.3125
#   Iteration: 39/57, Loss: 0.607863, Error: 0.3021
#   Iteration: 40/57, Loss: 0.640233, Error: 0.3333
#   Iteration: 41/57, Loss: 0.596564, Error: 0.3125
#   Iteration: 42/57, Loss: 0.588019, Error: 0.2812
#   Iteration: 43/57, Loss: 0.59895, Error: 0.3021
#   Iteration: 44/57, Loss: 0.586386, Error: 0.3021
#   Iteration: 45/57, Loss: 0.658894, Error: 0.3333
#   Iteration: 46/57, Loss: 0.611436, Error: 0.3021
#   Iteration: 47/57, Loss: 0.63092, Error: 0.3646
#   Iteration: 48/57, Loss: 0.633749, Error: 0.3438
#   Iteration: 49/57, Loss: 0.641022, Error: 0.3438
#   Iteration: 50/57, Loss: 0.627334, Error: 0.3021
#   Iteration: 51/57, Loss: 0.616682, Error: 0.3438
#   Iteration: 52/57, Loss: 0.656975, Error: 0.3542
#   Iteration: 53/57, Loss: 0.701885, Error: 0.4375
#   Iteration: 54/57, Loss: 0.617166, Error: 0.3125
#   Iteration: 55/57, Loss: 0.601376, Error: 0.3125
#   Iteration: 56/57, Loss: 0.639996, Error: 0.3646
#   Iteration: 57/57, Loss: 0.618045, Error: 0.3509
# Average Error for this Epoch: 0.3201
# Epoch: 3/10
#   Iteration: 1/57, Loss: 0.574999, Error: 0.2604
#   Iteration: 2/57, Loss: 0.597443, Error: 0.3125
#   Iteration: 3/57, Loss: 0.561433, Error: 0.2604
#   Iteration: 4/57, Loss: 0.642895, Error: 0.3438
#   Iteration: 5/57, Loss: 0.576246, Error: 0.2708
#   Iteration: 6/57, Loss: 0.604436, Error: 0.3229
#   Iteration: 7/57, Loss: 0.557748, Error: 0.2812
#   Iteration: 8/57, Loss: 0.664215, Error: 0.3646
#   Iteration: 9/57, Loss: 0.657725, Error: 0.3750
#   Iteration: 10/57, Loss: 0.606537, Error: 0.2812
#   Iteration: 11/57, Loss: 0.59126, Error: 0.2708
#   Iteration: 12/57, Loss: 0.539071, Error: 0.2188
#   Iteration: 13/57, Loss: 0.572519, Error: 0.2396
#   Iteration: 14/57, Loss: 0.628899, Error: 0.3333
#   Iteration: 15/57, Loss: 0.609077, Error: 0.3229
#   Iteration: 16/57, Loss: 0.543107, Error: 0.2188
#   Iteration: 17/57, Loss: 0.579236, Error: 0.2917
#   Iteration: 18/57, Loss: 0.625232, Error: 0.3333
#   Iteration: 19/57, Loss: 0.5879, Error: 0.2812
#   Iteration: 20/57, Loss: 0.606175, Error: 0.3021
#   Iteration: 21/57, Loss: 0.561444, Error: 0.2188
#   Iteration: 22/57, Loss: 0.656318, Error: 0.3646
#   Iteration: 23/57, Loss: 0.716181, Error: 0.4688
#   Iteration: 24/57, Loss: 0.63374, Error: 0.3438
#   Iteration: 25/57, Loss: 0.624733, Error: 0.3438
#   Iteration: 26/57, Loss: 0.663964, Error: 0.3333
#   Iteration: 27/57, Loss: 0.639561, Error: 0.3438
#   Iteration: 28/57, Loss: 0.602848, Error: 0.2812
#   Iteration: 29/57, Loss: 0.611431, Error: 0.3021
#   Iteration: 30/57, Loss: 0.636599, Error: 0.3438
#   Iteration: 31/57, Loss: 0.591203, Error: 0.2708
#   Iteration: 32/57, Loss: 0.608975, Error: 0.3125
#   Iteration: 33/57, Loss: 0.633758, Error: 0.3542
#   Iteration: 34/57, Loss: 0.548575, Error: 0.2604
#   Iteration: 35/57, Loss: 0.754764, Error: 0.4896
#   Iteration: 36/57, Loss: 0.630548, Error: 0.3438
#   Iteration: 37/57, Loss: 0.561181, Error: 0.2708
#   Iteration: 38/57, Loss: 0.617749, Error: 0.3229
#   Iteration: 39/57, Loss: 0.641782, Error: 0.3750
#   Iteration: 40/57, Loss: 0.597261, Error: 0.2812
#   Iteration: 41/57, Loss: 0.589571, Error: 0.2604
#   Iteration: 42/57, Loss: 0.558926, Error: 0.2917
#   Iteration: 43/57, Loss: 0.643074, Error: 0.3125
#   Iteration: 44/57, Loss: 0.657264, Error: 0.4062
#   Iteration: 45/57, Loss: 0.649547, Error: 0.3854
#   Iteration: 46/57, Loss: 0.635346, Error: 0.3646
#   Iteration: 47/57, Loss: 0.518448, Error: 0.2188
#   Iteration: 48/57, Loss: 0.649047, Error: 0.3750
#   Iteration: 49/57, Loss: 0.650173, Error: 0.3333
#   Iteration: 50/57, Loss: 0.615318, Error: 0.3125
#   Iteration: 51/57, Loss: 0.603259, Error: 0.2812
#   Iteration: 52/57, Loss: 0.63043, Error: 0.3021
#   Iteration: 53/57, Loss: 0.646505, Error: 0.3646
#   Iteration: 54/57, Loss: 0.639184, Error: 0.3438
#   Iteration: 55/57, Loss: 0.665511, Error: 0.4167
#   Iteration: 56/57, Loss: 0.679092, Error: 0.3958
#   Iteration: 57/57, Loss: 0.592272, Error: 0.2632
# Average Error for this Epoch: 0.3182
# found a better model!
# Epoch: 4/10
#   Iteration: 1/57, Loss: 0.688795, Error: 0.3750
#   Iteration: 2/57, Loss: 0.548005, Error: 0.2396
#   Iteration: 3/57, Loss: 0.679665, Error: 0.4479
#   Iteration: 4/57, Loss: 0.61988, Error: 0.3125
#   Iteration: 5/57, Loss: 0.544228, Error: 0.2083
#   Iteration: 6/57, Loss: 0.605448, Error: 0.3125
#   Iteration: 7/57, Loss: 0.654936, Error: 0.3750
#   Iteration: 8/57, Loss: 0.605153, Error: 0.3333
#   Iteration: 9/57, Loss: 0.636007, Error: 0.3750
#   Iteration: 10/57, Loss: 0.621241, Error: 0.3125
#   Iteration: 11/57, Loss: 0.682403, Error: 0.3750
#   Iteration: 12/57, Loss: 0.615659, Error: 0.3333
#   Iteration: 13/57, Loss: 0.690053, Error: 0.3542
#   Iteration: 14/57, Loss: 0.575106, Error: 0.2917
#   Iteration: 15/57, Loss: 0.606454, Error: 0.3125
#   Iteration: 16/57, Loss: 0.585965, Error: 0.2812
#   Iteration: 17/57, Loss: 0.623868, Error: 0.3438
#   Iteration: 18/57, Loss: 0.57781, Error: 0.2917
#   Iteration: 19/57, Loss: 0.582219, Error: 0.2500
#   Iteration: 20/57, Loss: 0.657371, Error: 0.4062
#   Iteration: 21/57, Loss: 0.646855, Error: 0.3438
#   Iteration: 22/57, Loss: 0.588198, Error: 0.3333
#   Iteration: 23/57, Loss: 0.642237, Error: 0.4062
#   Iteration: 24/57, Loss: 0.607902, Error: 0.2917
#   Iteration: 25/57, Loss: 0.577337, Error: 0.2812
#   Iteration: 26/57, Loss: 0.586167, Error: 0.2917
#   Iteration: 27/57, Loss: 0.626669, Error: 0.3229
#   Iteration: 28/57, Loss: 0.668679, Error: 0.3542
#   Iteration: 29/57, Loss: 0.596151, Error: 0.2812
#   Iteration: 30/57, Loss: 0.673852, Error: 0.4167
#   Iteration: 31/57, Loss: 0.616311, Error: 0.3125
#   Iteration: 32/57, Loss: 0.60514, Error: 0.2917
#   Iteration: 33/57, Loss: 0.664785, Error: 0.3646
#   Iteration: 34/57, Loss: 0.673965, Error: 0.3854
#   Iteration: 35/57, Loss: 0.569574, Error: 0.2917
#   Iteration: 36/57, Loss: 0.637751, Error: 0.3750
#   Iteration: 37/57, Loss: 0.575001, Error: 0.2500
#   Iteration: 38/57, Loss: 0.624291, Error: 0.3229
#   Iteration: 39/57, Loss: 0.633462, Error: 0.3542
#   Iteration: 40/57, Loss: 0.570436, Error: 0.3229
#   Iteration: 41/57, Loss: 0.610886, Error: 0.2917
#   Iteration: 42/57, Loss: 0.600464, Error: 0.3021
#   Iteration: 43/57, Loss: 0.587631, Error: 0.2708
#   Iteration: 44/57, Loss: 0.650014, Error: 0.3646
#   Iteration: 45/57, Loss: 0.639216, Error: 0.3438
#   Iteration: 46/57, Loss: 0.628889, Error: 0.3438
#   Iteration: 47/57, Loss: 0.580882, Error: 0.2708
#   Iteration: 48/57, Loss: 0.632602, Error: 0.3542
#   Iteration: 49/57, Loss: 0.61747, Error: 0.3021
#   Iteration: 50/57, Loss: 0.583383, Error: 0.2708
#   Iteration: 51/57, Loss: 0.646349, Error: 0.3750
#   Iteration: 52/57, Loss: 0.574051, Error: 0.2708
#   Iteration: 53/57, Loss: 0.553561, Error: 0.2188
#   Iteration: 54/57, Loss: 0.589448, Error: 0.2708
#   Iteration: 55/57, Loss: 0.617286, Error: 0.3229
#   Iteration: 56/57, Loss: 0.550526, Error: 0.2188
#   Iteration: 57/57, Loss: 0.667153, Error: 0.3158
# Average Error for this Epoch: 0.3199
# Epoch: 5/10
#   Iteration: 1/57, Loss: 0.6725, Error: 0.4167
#   Iteration: 2/57, Loss: 0.603464, Error: 0.3229
#   Iteration: 3/57, Loss: 0.610093, Error: 0.3229
#   Iteration: 4/57, Loss: 0.611427, Error: 0.3125
#   Iteration: 5/57, Loss: 0.64227, Error: 0.3333
#   Iteration: 6/57, Loss: 0.605099, Error: 0.3021
#   Iteration: 7/57, Loss: 0.610172, Error: 0.3229
#   Iteration: 8/57, Loss: 0.5737, Error: 0.2500
#   Iteration: 9/57, Loss: 0.59998, Error: 0.3125
#   Iteration: 10/57, Loss: 0.649277, Error: 0.3646
#   Iteration: 11/57, Loss: 0.609682, Error: 0.3125
#   Iteration: 12/57, Loss: 0.635698, Error: 0.3333
#   Iteration: 13/57, Loss: 0.610029, Error: 0.3125
#   Iteration: 14/57, Loss: 0.676561, Error: 0.3958
#   Iteration: 15/57, Loss: 0.593643, Error: 0.2812
#   Iteration: 16/57, Loss: 0.608728, Error: 0.3229
#   Iteration: 17/57, Loss: 0.683498, Error: 0.4062
#   Iteration: 18/57, Loss: 0.578782, Error: 0.2500
#   Iteration: 19/57, Loss: 0.65926, Error: 0.3646
#   Iteration: 20/57, Loss: 0.674993, Error: 0.4062
#   Iteration: 21/57, Loss: 0.616323, Error: 0.3542
#   Iteration: 22/57, Loss: 0.566555, Error: 0.2812
#   Iteration: 23/57, Loss: 0.646528, Error: 0.3438
#   Iteration: 24/57, Loss: 0.67129, Error: 0.3854
#   Iteration: 25/57, Loss: 0.608536, Error: 0.2812
#   Iteration: 26/57, Loss: 0.655896, Error: 0.3542
#   Iteration: 27/57, Loss: 0.681099, Error: 0.3854
#   Iteration: 28/57, Loss: 0.648208, Error: 0.3542
#   Iteration: 29/57, Loss: 0.636216, Error: 0.3542
#   Iteration: 30/57, Loss: 0.566978, Error: 0.2500
#   Iteration: 31/57, Loss: 0.624833, Error: 0.3229
#   Iteration: 32/57, Loss: 0.601036, Error: 0.3021
#   Iteration: 33/57, Loss: 0.608496, Error: 0.3125
#   Iteration: 34/57, Loss: 0.619549, Error: 0.3125
#   Iteration: 35/57, Loss: 0.586604, Error: 0.3021
#   Iteration: 36/57, Loss: 0.587653, Error: 0.2396
#   Iteration: 37/57, Loss: 0.621466, Error: 0.3125
#   Iteration: 38/57, Loss: 0.582204, Error: 0.3125
#   Iteration: 39/57, Loss: 0.629531, Error: 0.3021
#   Iteration: 40/57, Loss: 0.596267, Error: 0.3021
#   Iteration: 41/57, Loss: 0.598898, Error: 0.3229
#   Iteration: 42/57, Loss: 0.624148, Error: 0.3542
#   Iteration: 43/57, Loss: 0.608361, Error: 0.3229
#   Iteration: 44/57, Loss: 0.574631, Error: 0.2500
#   Iteration: 45/57, Loss: 0.627439, Error: 0.3229
#   Iteration: 46/57, Loss: 0.598899, Error: 0.2917
#   Iteration: 47/57, Loss: 0.547853, Error: 0.2396
#   Iteration: 48/57, Loss: 0.598256, Error: 0.3229
#   Iteration: 49/57, Loss: 0.563108, Error: 0.2604
#   Iteration: 50/57, Loss: 0.609183, Error: 0.3438
#   Iteration: 51/57, Loss: 0.599544, Error: 0.2917
#   Iteration: 52/57, Loss: 0.567041, Error: 0.2917
#   Iteration: 53/57, Loss: 0.636869, Error: 0.3438
#   Iteration: 54/57, Loss: 0.582683, Error: 0.3021
#   Iteration: 55/57, Loss: 0.61718, Error: 0.3229
#   Iteration: 56/57, Loss: 0.647504, Error: 0.3438
#   Iteration: 57/57, Loss: 0.597748, Error: 0.2807
# Average Error for this Epoch: 0.3196
# Epoch: 6/10
#   Iteration: 1/57, Loss: 0.652087, Error: 0.3542
#   Iteration: 2/57, Loss: 0.61626, Error: 0.2917
#   Iteration: 3/57, Loss: 0.630489, Error: 0.3542
#   Iteration: 4/57, Loss: 0.560911, Error: 0.2604
#   Iteration: 5/57, Loss: 0.595431, Error: 0.2917
#   Iteration: 6/57, Loss: 0.587297, Error: 0.2708
#   Iteration: 7/57, Loss: 0.639342, Error: 0.3750
#   Iteration: 8/57, Loss: 0.634417, Error: 0.3542
#   Iteration: 9/57, Loss: 0.614132, Error: 0.2917
#   Iteration: 10/57, Loss: 0.601321, Error: 0.2917
#   Iteration: 11/57, Loss: 0.59252, Error: 0.3125
#   Iteration: 12/57, Loss: 0.635877, Error: 0.3229
#   Iteration: 13/57, Loss: 0.646711, Error: 0.3542
#   Iteration: 14/57, Loss: 0.599553, Error: 0.3438
#   Iteration: 15/57, Loss: 0.635564, Error: 0.3646
#   Iteration: 16/57, Loss: 0.627492, Error: 0.3125
#   Iteration: 17/57, Loss: 0.663903, Error: 0.3542
#   Iteration: 18/57, Loss: 0.630006, Error: 0.3438
#   Iteration: 19/57, Loss: 0.639611, Error: 0.3333
#   Iteration: 20/57, Loss: 0.657709, Error: 0.3542
#   Iteration: 21/57, Loss: 0.551683, Error: 0.2292
#   Iteration: 22/57, Loss: 0.581325, Error: 0.3229
#   Iteration: 23/57, Loss: 0.539733, Error: 0.2292
#   Iteration: 24/57, Loss: 0.618555, Error: 0.3021
#   Iteration: 25/57, Loss: 0.638354, Error: 0.3958
#   Iteration: 26/57, Loss: 0.603606, Error: 0.3021
#   Iteration: 27/57, Loss: 0.599665, Error: 0.2604
#   Iteration: 28/57, Loss: 0.603882, Error: 0.3333
#   Iteration: 29/57, Loss: 0.551875, Error: 0.2708
#   Iteration: 30/57, Loss: 0.622799, Error: 0.3333
#   Iteration: 31/57, Loss: 0.580959, Error: 0.3021
#   Iteration: 32/57, Loss: 0.65762, Error: 0.3750
#   Iteration: 33/57, Loss: 0.581605, Error: 0.2708
#   Iteration: 34/57, Loss: 0.591705, Error: 0.3021
#   Iteration: 35/57, Loss: 0.658222, Error: 0.3646
#   Iteration: 36/57, Loss: 0.618127, Error: 0.3229
#   Iteration: 37/57, Loss: 0.64647, Error: 0.3958
#   Iteration: 38/57, Loss: 0.631962, Error: 0.3229
#   Iteration: 39/57, Loss: 0.610681, Error: 0.3229
#   Iteration: 40/57, Loss: 0.649127, Error: 0.3542
#   Iteration: 41/57, Loss: 0.594741, Error: 0.2917
#   Iteration: 42/57, Loss: 0.582987, Error: 0.2812
#   Iteration: 43/57, Loss: 0.653972, Error: 0.3542
#   Iteration: 44/57, Loss: 0.631498, Error: 0.3125
#   Iteration: 45/57, Loss: 0.651402, Error: 0.3646
#   Iteration: 46/57, Loss: 0.646238, Error: 0.3646
#   Iteration: 47/57, Loss: 0.587419, Error: 0.2604
#   Iteration: 48/57, Loss: 0.569293, Error: 0.2604
#   Iteration: 49/57, Loss: 0.600723, Error: 0.3229
#   Iteration: 50/57, Loss: 0.617312, Error: 0.3542
#   Iteration: 51/57, Loss: 0.674677, Error: 0.3542
#   Iteration: 52/57, Loss: 0.627324, Error: 0.3021
#   Iteration: 53/57, Loss: 0.628418, Error: 0.3750
#   Iteration: 54/57, Loss: 0.604295, Error: 0.2604
#   Iteration: 55/57, Loss: 0.581653, Error: 0.3229
#   Iteration: 56/57, Loss: 0.550882, Error: 0.2292
#   Iteration: 57/57, Loss: 0.734758, Error: 0.4386
# Average Error for this Epoch: 0.3209
# Epoch: 7/10
#   Iteration: 1/57, Loss: 0.560955, Error: 0.2396
#   Iteration: 2/57, Loss: 0.629288, Error: 0.3750
#   Iteration: 3/57, Loss: 0.653101, Error: 0.3750
#   Iteration: 4/57, Loss: 0.597586, Error: 0.2917
#   Iteration: 5/57, Loss: 0.61176, Error: 0.2708
#   Iteration: 6/57, Loss: 0.609348, Error: 0.3229
#   Iteration: 7/57, Loss: 0.665386, Error: 0.3750
#   Iteration: 8/57, Loss: 0.592872, Error: 0.2917
#   Iteration: 9/57, Loss: 0.633332, Error: 0.3021
#   Iteration: 10/57, Loss: 0.662445, Error: 0.3646
#   Iteration: 11/57, Loss: 0.64061, Error: 0.3333
#   Iteration: 12/57, Loss: 0.629457, Error: 0.3438
#   Iteration: 13/57, Loss: 0.634466, Error: 0.3542
#   Iteration: 14/57, Loss: 0.592246, Error: 0.2604
#   Iteration: 15/57, Loss: 0.665448, Error: 0.3438
#   Iteration: 16/57, Loss: 0.620736, Error: 0.3021
#   Iteration: 17/57, Loss: 0.656478, Error: 0.3646
#   Iteration: 18/57, Loss: 0.64629, Error: 0.3646
#   Iteration: 19/57, Loss: 0.561834, Error: 0.2812
#   Iteration: 20/57, Loss: 0.670835, Error: 0.3646
#   Iteration: 21/57, Loss: 0.663976, Error: 0.3958
#   Iteration: 22/57, Loss: 0.591025, Error: 0.3125
#   Iteration: 23/57, Loss: 0.638469, Error: 0.3750
#   Iteration: 24/57, Loss: 0.522632, Error: 0.2083
#   Iteration: 25/57, Loss: 0.625453, Error: 0.3333
#   Iteration: 26/57, Loss: 0.527315, Error: 0.2083
#   Iteration: 27/57, Loss: 0.561765, Error: 0.2500
#   Iteration: 28/57, Loss: 0.592724, Error: 0.3125
#   Iteration: 29/57, Loss: 0.587897, Error: 0.3021
#   Iteration: 30/57, Loss: 0.587575, Error: 0.2708
#   Iteration: 31/57, Loss: 0.553241, Error: 0.2292
#   Iteration: 32/57, Loss: 0.691907, Error: 0.4167
#   Iteration: 33/57, Loss: 0.649701, Error: 0.3542
#   Iteration: 34/57, Loss: 0.649861, Error: 0.3542
#   Iteration: 35/57, Loss: 0.587898, Error: 0.3125
#   Iteration: 36/57, Loss: 0.522032, Error: 0.2396
#   Iteration: 37/57, Loss: 0.553103, Error: 0.2500
#   Iteration: 38/57, Loss: 0.618495, Error: 0.3542
#   Iteration: 39/57, Loss: 0.579839, Error: 0.2500
#   Iteration: 40/57, Loss: 0.641104, Error: 0.3438
#   Iteration: 41/57, Loss: 0.605939, Error: 0.3021
#   Iteration: 42/57, Loss: 0.647967, Error: 0.3854
#   Iteration: 43/57, Loss: 0.618123, Error: 0.3333
#   Iteration: 44/57, Loss: 0.568741, Error: 0.2917
#   Iteration: 45/57, Loss: 0.618182, Error: 0.3229
#   Iteration: 46/57, Loss: 0.61182, Error: 0.3333
#   Iteration: 47/57, Loss: 0.643104, Error: 0.3125
#   Iteration: 48/57, Loss: 0.608073, Error: 0.3333
#   Iteration: 49/57, Loss: 0.653286, Error: 0.3438
#   Iteration: 50/57, Loss: 0.616751, Error: 0.3333
#   Iteration: 51/57, Loss: 0.647613, Error: 0.3958
#   Iteration: 52/57, Loss: 0.630582, Error: 0.3229
#   Iteration: 53/57, Loss: 0.650755, Error: 0.3438
#   Iteration: 54/57, Loss: 0.63615, Error: 0.3542
#   Iteration: 55/57, Loss: 0.591456, Error: 0.2812
#   Iteration: 56/57, Loss: 0.674779, Error: 0.3438
#   Iteration: 57/57, Loss: 0.544596, Error: 0.2632
# Average Error for this Epoch: 0.3191
# Epoch: 8/10
#   Iteration: 1/57, Loss: 0.606041, Error: 0.3125
#   Iteration: 2/57, Loss: 0.590342, Error: 0.2812
#   Iteration: 3/57, Loss: 0.62953, Error: 0.3438
#   Iteration: 4/57, Loss: 0.642047, Error: 0.3750
#   Iteration: 5/57, Loss: 0.577952, Error: 0.2604
#   Iteration: 6/57, Loss: 0.578783, Error: 0.2917
#   Iteration: 7/57, Loss: 0.58754, Error: 0.2917
#   Iteration: 8/57, Loss: 0.640408, Error: 0.3438
#   Iteration: 9/57, Loss: 0.630325, Error: 0.3438
#   Iteration: 10/57, Loss: 0.547477, Error: 0.2500
#   Iteration: 11/57, Loss: 0.614922, Error: 0.3542
#   Iteration: 12/57, Loss: 0.636671, Error: 0.3542
#   Iteration: 13/57, Loss: 0.590135, Error: 0.2917
#   Iteration: 14/57, Loss: 0.630787, Error: 0.3333
#   Iteration: 15/57, Loss: 0.678979, Error: 0.3854
#   Iteration: 16/57, Loss: 0.620229, Error: 0.3229
#   Iteration: 17/57, Loss: 0.614568, Error: 0.3021
#   Iteration: 18/57, Loss: 0.62817, Error: 0.3229
#   Iteration: 19/57, Loss: 0.650489, Error: 0.3438
#   Iteration: 20/57, Loss: 0.614012, Error: 0.2812
#   Iteration: 21/57, Loss: 0.648603, Error: 0.3646
#   Iteration: 22/57, Loss: 0.581854, Error: 0.2917
#   Iteration: 23/57, Loss: 0.587282, Error: 0.2812
#   Iteration: 24/57, Loss: 0.622675, Error: 0.3542
#   Iteration: 25/57, Loss: 0.568329, Error: 0.2708
#   Iteration: 26/57, Loss: 0.605439, Error: 0.3021
#   Iteration: 27/57, Loss: 0.63766, Error: 0.3333
#   Iteration: 28/57, Loss: 0.626042, Error: 0.3125
#   Iteration: 29/57, Loss: 0.654595, Error: 0.3438
#   Iteration: 30/57, Loss: 0.566786, Error: 0.2396
#   Iteration: 31/57, Loss: 0.536723, Error: 0.2292
#   Iteration: 32/57, Loss: 0.694868, Error: 0.4062
#   Iteration: 33/57, Loss: 0.592584, Error: 0.3021
#   Iteration: 34/57, Loss: 0.556126, Error: 0.2812
#   Iteration: 35/57, Loss: 0.589477, Error: 0.2708
#   Iteration: 36/57, Loss: 0.647772, Error: 0.3750
#   Iteration: 37/57, Loss: 0.63179, Error: 0.3438
#   Iteration: 38/57, Loss: 0.576654, Error: 0.2604
#   Iteration: 39/57, Loss: 0.662703, Error: 0.3646
#   Iteration: 40/57, Loss: 0.619097, Error: 0.3125
#   Iteration: 41/57, Loss: 0.650372, Error: 0.3750
#   Iteration: 42/57, Loss: 0.561584, Error: 0.2396
#   Iteration: 43/57, Loss: 0.599821, Error: 0.3021
#   Iteration: 44/57, Loss: 0.608916, Error: 0.3125
#   Iteration: 45/57, Loss: 0.631936, Error: 0.3438
#   Iteration: 46/57, Loss: 0.586685, Error: 0.2917
#   Iteration: 47/57, Loss: 0.655961, Error: 0.3542
#   Iteration: 48/57, Loss: 0.632719, Error: 0.3646
#   Iteration: 49/57, Loss: 0.606157, Error: 0.3021
#   Iteration: 50/57, Loss: 0.60248, Error: 0.3021
#   Iteration: 51/57, Loss: 0.551264, Error: 0.2500
#   Iteration: 52/57, Loss: 0.674882, Error: 0.3958
#   Iteration: 53/57, Loss: 0.623971, Error: 0.3229
#   Iteration: 54/57, Loss: 0.690853, Error: 0.4167
#   Iteration: 55/57, Loss: 0.613318, Error: 0.3229
#   Iteration: 56/57, Loss: 0.669253, Error: 0.3958
#   Iteration: 57/57, Loss: 0.588069, Error: 0.3333
# Average Error for this Epoch: 0.3202
# Epoch: 9/10
#   Iteration: 1/57, Loss: 0.561726, Error: 0.2500
#   Iteration: 2/57, Loss: 0.61758, Error: 0.3021
#   Iteration: 3/57, Loss: 0.587418, Error: 0.3229
#   Iteration: 4/57, Loss: 0.587464, Error: 0.2812
#   Iteration: 5/57, Loss: 0.615733, Error: 0.3229
#   Iteration: 6/57, Loss: 0.645062, Error: 0.3438
#   Iteration: 7/57, Loss: 0.604747, Error: 0.2708
#   Iteration: 8/57, Loss: 0.630797, Error: 0.3333
#   Iteration: 9/57, Loss: 0.624145, Error: 0.3750
#   Iteration: 10/57, Loss: 0.569601, Error: 0.2604
#   Iteration: 11/57, Loss: 0.6352, Error: 0.3438
#   Iteration: 12/57, Loss: 0.57777, Error: 0.2708
#   Iteration: 13/57, Loss: 0.685279, Error: 0.3750
#   Iteration: 14/57, Loss: 0.5573, Error: 0.2604
#   Iteration: 15/57, Loss: 0.63921, Error: 0.3542
#   Iteration: 16/57, Loss: 0.636949, Error: 0.3854
#   Iteration: 17/57, Loss: 0.631717, Error: 0.3438
#   Iteration: 18/57, Loss: 0.587859, Error: 0.2604
#   Iteration: 19/57, Loss: 0.606899, Error: 0.3021
#   Iteration: 20/57, Loss: 0.725756, Error: 0.4792
#   Iteration: 21/57, Loss: 0.606419, Error: 0.2917
#   Iteration: 22/57, Loss: 0.64247, Error: 0.3646
#   Iteration: 23/57, Loss: 0.600843, Error: 0.2812
#   Iteration: 24/57, Loss: 0.620944, Error: 0.3750
#   Iteration: 25/57, Loss: 0.64744, Error: 0.3646
#   Iteration: 26/57, Loss: 0.622766, Error: 0.3333
#   Iteration: 27/57, Loss: 0.59876, Error: 0.3125
#   Iteration: 28/57, Loss: 0.643258, Error: 0.3542
#   Iteration: 29/57, Loss: 0.598759, Error: 0.2917
#   Iteration: 30/57, Loss: 0.569916, Error: 0.3021
#   Iteration: 31/57, Loss: 0.625857, Error: 0.3438
#   Iteration: 32/57, Loss: 0.608913, Error: 0.3438
#   Iteration: 33/57, Loss: 0.636903, Error: 0.3542
#   Iteration: 34/57, Loss: 0.574109, Error: 0.2604
#   Iteration: 35/57, Loss: 0.592258, Error: 0.2917
#   Iteration: 36/57, Loss: 0.600883, Error: 0.2812
#   Iteration: 37/57, Loss: 0.592461, Error: 0.3125
#   Iteration: 38/57, Loss: 0.583916, Error: 0.2708
#   Iteration: 39/57, Loss: 0.605017, Error: 0.3125
#   Iteration: 40/57, Loss: 0.597432, Error: 0.3125
#   Iteration: 41/57, Loss: 0.580423, Error: 0.2812
#   Iteration: 42/57, Loss: 0.670192, Error: 0.3646
#   Iteration: 43/57, Loss: 0.635134, Error: 0.3438
#   Iteration: 44/57, Loss: 0.61641, Error: 0.2812
#   Iteration: 45/57, Loss: 0.620185, Error: 0.3125
#   Iteration: 46/57, Loss: 0.610993, Error: 0.3438
#   Iteration: 47/57, Loss: 0.610801, Error: 0.3333
#   Iteration: 48/57, Loss: 0.63443, Error: 0.3542
#   Iteration: 49/57, Loss: 0.641748, Error: 0.3438
#   Iteration: 50/57, Loss: 0.626497, Error: 0.3125
#   Iteration: 51/57, Loss: 0.657802, Error: 0.3646
#   Iteration: 52/57, Loss: 0.596236, Error: 0.2604
#   Iteration: 53/57, Loss: 0.636381, Error: 0.3750
#   Iteration: 54/57, Loss: 0.585437, Error: 0.2708
#   Iteration: 55/57, Loss: 0.61284, Error: 0.3021
#   Iteration: 56/57, Loss: 0.575454, Error: 0.2708
#   Iteration: 57/57, Loss: 0.692659, Error: 0.3684
# Average Error for this Epoch: 0.3206
# Epoch: 10/10
#   Iteration: 1/57, Loss: 0.633229, Error: 0.3542
#   Iteration: 2/57, Loss: 0.562006, Error: 0.2812
#   Iteration: 3/57, Loss: 0.554171, Error: 0.2500
#   Iteration: 4/57, Loss: 0.62333, Error: 0.3646
#   Iteration: 5/57, Loss: 0.654851, Error: 0.3646
#   Iteration: 6/57, Loss: 0.620374, Error: 0.2812
#   Iteration: 7/57, Loss: 0.607024, Error: 0.3125
#   Iteration: 8/57, Loss: 0.529717, Error: 0.2083
#   Iteration: 9/57, Loss: 0.605814, Error: 0.2812
#   Iteration: 10/57, Loss: 0.615045, Error: 0.3438
#   Iteration: 11/57, Loss: 0.56838, Error: 0.2708
#   Iteration: 12/57, Loss: 0.632435, Error: 0.3750
#   Iteration: 13/57, Loss: 0.660601, Error: 0.3125
#   Iteration: 14/57, Loss: 0.659181, Error: 0.3438
#   Iteration: 15/57, Loss: 0.621051, Error: 0.3125
#   Iteration: 16/57, Loss: 0.616292, Error: 0.3229
#   Iteration: 17/57, Loss: 0.573515, Error: 0.2917
#   Iteration: 18/57, Loss: 0.678294, Error: 0.3854
#   Iteration: 19/57, Loss: 0.605708, Error: 0.3021
#   Iteration: 20/57, Loss: 0.605048, Error: 0.3229
#   Iteration: 21/57, Loss: 0.598476, Error: 0.3229
#   Iteration: 22/57, Loss: 0.60872, Error: 0.2917
#   Iteration: 23/57, Loss: 0.59614, Error: 0.2812
#   Iteration: 24/57, Loss: 0.57002, Error: 0.2708
#   Iteration: 25/57, Loss: 0.622753, Error: 0.3542
#   Iteration: 26/57, Loss: 0.643216, Error: 0.3438
#   Iteration: 27/57, Loss: 0.583024, Error: 0.3021
#   Iteration: 28/57, Loss: 0.626357, Error: 0.3125
#   Iteration: 29/57, Loss: 0.621001, Error: 0.3333
#   Iteration: 30/57, Loss: 0.584706, Error: 0.2917
#   Iteration: 31/57, Loss: 0.669051, Error: 0.4062
#   Iteration: 32/57, Loss: 0.623534, Error: 0.3646
#   Iteration: 33/57, Loss: 0.651918, Error: 0.3646
#   Iteration: 34/57, Loss: 0.612505, Error: 0.3021
#   Iteration: 35/57, Loss: 0.681176, Error: 0.3750
#   Iteration: 36/57, Loss: 0.591462, Error: 0.3125
#   Iteration: 37/57, Loss: 0.640915, Error: 0.3229
#   Iteration: 38/57, Loss: 0.639916, Error: 0.3438
#   Iteration: 39/57, Loss: 0.595256, Error: 0.2708
#   Iteration: 40/57, Loss: 0.593579, Error: 0.3333
#   Iteration: 41/57, Loss: 0.576858, Error: 0.3021
#   Iteration: 42/57, Loss: 0.691335, Error: 0.3958
#   Iteration: 43/57, Loss: 0.62886, Error: 0.3229
#   Iteration: 44/57, Loss: 0.619036, Error: 0.3229
#   Iteration: 45/57, Loss: 0.585694, Error: 0.3125
#   Iteration: 46/57, Loss: 0.654215, Error: 0.3542
#   Iteration: 47/57, Loss: 0.637552, Error: 0.3438
#   Iteration: 48/57, Loss: 0.564228, Error: 0.2917
#   Iteration: 49/57, Loss: 0.597923, Error: 0.2708
#   Iteration: 50/57, Loss: 0.647739, Error: 0.3438
#   Iteration: 51/57, Loss: 0.632442, Error: 0.3021
#   Iteration: 52/57, Loss: 0.679687, Error: 0.3854
#   Iteration: 53/57, Loss: 0.608862, Error: 0.2708
#   Iteration: 54/57, Loss: 0.59006, Error: 0.2917
#   Iteration: 55/57, Loss: 0.622555, Error: 0.3542
#   Iteration: 56/57, Loss: 0.587424, Error: 0.2812
#   Iteration: 57/57, Loss: 0.552772, Error: 0.2807
# Average Error for this Epoch: 0.3194

# %%
plt.figure()
plt.plot(np.linspace(start=1, stop=num_epochs, num=num_epochs), avg_error_vec)
plt.xlabel("Number of Epochs")
plt.ylabel("Average Training Error")
plt.title("Average Training Error for Epochs=1:100")
plt.grid(True)
# plt.savefig("Neural Net Training Error.jpg")

# %% [markdown]
# ## Evaluate model on testing set

# %%
best_model.eval()

for i, (samples, labels) in enumerate(test_loader):
    samples = Variable(samples)
    labels = Variable(labels)
    predictions = best_model(samples)
    predictions = torch.flatten(predictions)
    labels = labels.type(torch.DoubleTensor)

    for j in range(0, predictions.size()[0]):
        if predictions[j] < 0.5:
            predictions[j] = 0
        else:
            predictions[j] = 1
    
    error = 1 - torch.sum(predictions == labels).item() / labels.size()[0]
    
    print("Testing set Error: %0.4f" % error)
    
model_path = dest_path + "torch_model_3_24_19_lr=" + str(learning_rate) + "_all_data_no_categorical_dict.pt"
# Out:
# Testing set Error: 0.3760

# %% [markdown]
# ### Save Model

# %%
torch.save(model.state_dict(), model_path)

# %% [markdown]
# ### Load and Evaluate previous models

# %%
model = CLANet(input_size, hidden_size, output_size)
model.load_state_dict(torch.load(dest_path + "torch_model_3_24_19_lr=0.01all_data_no_categorical_dict.pt"))
model.double()     # cast model parameters to double
model.eval()

for i, (samples, labels) in enumerate(test_loader):
    samples = Variable(samples)
    labels = Variable(labels)
    conf = model(samples)
    conf = torch.flatten(conf)
    labels = labels.type(torch.DoubleTensor)
    
    for j in range(conf.size()[0]):
        if conf[j] < 0.5:
            conf[j] = 0
        else:
            conf[j] = 1
                
    error = 1 - torch.sum(conf == labels).item() / labels.size()[0]
    
    print("Testing set Error: %0.4f" % error)
# Out:
# Testing set Error: 0.3767

# %% [markdown]
# ## Best Model Evaluation

# %%
model = CLANet(input_size, hidden_size, output_size)
model.load_state_dict(torch.load(dest_path + "torch_model_3_24_19_lr=0.01all_data_no_categorical_dict.pt"))
model.double()     # cast model parameters to double
model.eval()

for i, (samples, labels) in enumerate(test_loader):
    samples = Variable(samples)
    labels = Variable(labels)
    conf = model(samples)    # confidence that a certain instance is predicted correctly
    conf = torch.flatten(conf)
    labels = labels.type(torch.DoubleTensor)
    
# convert to numpy arrays
conf = conf.detach().numpy()
labels = labels.numpy()

# sort arrays according to the predicted confidence (high confidence to low confidence)
sort_idx = np.argsort(-conf, kind='mergesort')
conf = conf[sort_idx]
labels = labels[sort_idx]

# %% [markdown]
# ### ROC Curve

# %%
num_pos = 0
num_neg = 0

for label in labels:
    if label < 0.5:
        num_neg += 1
    else:
        num_pos += 1
        
tp = 0
fp = 0
last_tp = 0
fpr = []
tpr = []

for i in range(len(labels)):
    if (i > 1) and (conf[i] != conf[i-1]) and (labels[i] == 0) and (tp > last_tp):
        fpr.append(fp / num_neg)
        tpr.append(tp / num_pos)
        last_tp = tp
    if labels[i] == 1:
        tp += 1
    else:
        fp += 1
        
fpr.append(fp / num_neg)
tpr.append(tp / num_pos)

plt.figure(figsize=(12, 8))
plt.plot(fpr, tpr)
plt.xlabel('False Postive Rate (FPR)', fontsize=20)
plt.ylabel('True Positive Rate (TPR)', fontsize=20)
plt.axis([0, 1, 0, 1.001])
plt.title('ROC Curve', fontsize=20)
plt.tight_layout()
plt.grid(True)

# %% [markdown]
# ### PR Curve

# %%
for i, (samples, labels) in enumerate(test_loader):
    samples = Variable(samples)
    labels = Variable(labels)
    pred = model(samples)
    pred = torch.flatten(pred)
    labels = labels.type(torch.DoubleTensor)

# convert to numpy arrays
pred = pred.detach().numpy()
labels = labels.numpy()

# sort arrays according to the predicted confidence (high confidence to low confidence)
sort_idx = np.argsort(-pred, kind='mergesort')
pred = pred[sort_idx]
labels = labels[sort_idx]

num_pred_pos = 0
num_actual_pos = 0
num_tp = 0
precision = []
recall = []

for confidence in conf:
    for i in range(len(pred)):
        if pred[i] >= confidence:
            num_pred_pos += 1
            
            if labels[i] == 1:
                num_tp += 1
        
        if labels[i] == 1:
            num_actual_pos += 1

    precision.append(num_tp / num_pred_pos)
    recall.append(num_tp / num_actual_pos)
    
    num_pred_pos = 0
    num_actual_pos = 0
    num_tp = 0

plt.figure(figsize=(12, 8))
plt.plot(recall, precision)
plt.xlabel('Recall', fontsize=20)
plt.ylabel('Precision', fontsize=20)
plt.axis([0, 1.001, 0.4, 1])
plt.title('PR Curve', fontsize=20)
plt.tight_layout()
plt.grid(True)

# %% [markdown]
# ## Test best model on other data sets

# %% [markdown]
# ### Read in data

# %%
# define data path
data_path = "/Users/Alliot/Documents/CLA-Project/Data/data-sets/"
data_set = "all_data_summer"

# load data sets
X = np.load(data_path + data_set + "_no_categorical.npy")
y = np.load(data_path + data_set + "_labels.npy")

# manipulate data set. labels are converted to 0, +1 for binary classification; samples are removed uniformly 
# from the data set so that the disproportionately large number of negative samples (no algae) does 
# not bias the model.

num_alg = 0  # count the number of algae instances
num_no_alg = 0  # count the number of no algae instances

# Convert labels to binary: -1 for no algae and 1 for algae
for i in range(0, len(y)):
    if y[i] == 0:
        num_no_alg += 1
    if y[i] == 1 or y[i] == 2:
        y[i] = 1
        num_alg += 1

# oversample the data set by randomly adding occurences of algae until the difference between the number of algae
# samples and no algae samples equals sample_bias (defined below)
idx = 0
sample_bias = 0
length_y = len(y)
while num_alg != (num_no_alg + sample_bias):
    # circle through the data sets until the difference of num_no_alg and num_alg equals
    # the value specified by sample_bias
    if idx == (length_y - 1):
        idx = 0

    if y[idx] == 1:
        if np.random.rand() >= 0.5:  # add this sample with some probability
            y = np.append(y, y[idx])
            X = np.append(X, np.reshape(X[idx, :], newshape=(1, num_features)), axis=0)
            num_alg += 1
        else:
            idx += 1
    else:
        idx += 1

# %% [markdown]
# ### Process and split data

# %%
# standardize data: remove the mean and variance in each sample
num_splits = 2   # do not change
sss = model_selection.StratifiedShuffleSplit(n_splits=num_splits, test_size=test_size)

idx, _ = sss.split(X, y);
train_idx = idx[0]
test_idx = idx[1]
X_train, X_test = X[train_idx], X[test_idx]
y_train, y_test = y[train_idx], y[test_idx]

X_train = preprocessing.scale(X_train, axis=1, with_mean=True, with_std=True)
X_test = preprocessing.scale(X_test, axis=1, with_mean=True, with_std=True)

# convert numpy arrays to pytorch tensors
train_set_size = X_train.shape
test_set_size = X_test.shape
X_train, X_test = torch.from_numpy(X_train), torch.from_numpy(X_test)
y_train, y_test = torch.from_numpy(y_train), torch.from_numpy(y_test)

# convert pytorch tensors to pytorch TensorDataset
train_set = utils.TensorDataset(X_train, y_train)
test_set = utils.TensorDataset(X_test, y_test)

# create DataLoaders
train_loader = utils.DataLoader(train_set, batch_size=batch_size, shuffle=True)
test_loader = utils.DataLoader(test_set, batch_size=test_set_size[0], shuffle=True)

# %% [markdown]
# ### Evaluate best model

# %%
for i, (samples, labels) in enumerate(test_loader):
    samples = Variable(samples)
    labels = Variable(labels)
    conf = model(samples)
    conf = torch.flatten(conf)
    labels = labels.type(torch.DoubleTensor)
    
    for j in range(conf.size()[0]):
        if conf[j] < 0.5:
            conf[j] = 0
        else:
            conf[j] = 1
                
    error = 1 - torch.sum(conf == labels).item() / labels.size()[0]
    
    print("Testing set Error: %0.4f" % error)
# Out:
# Testing set Error: 0.3481

# %% [markdown]
# ### Optimizer parameter adjust

# %%
for p in optimizer.param_groups:
    p["lr"] = 0.003
    p["momentum"] = 0.5

# %%
for p in optimizer.param_groups:
    p["lr"] = 0.001
    p["momentum"] = 0.2

# %%
for p in optimizer.param_groups:
    p["lr"] = 0.00001
    p["momentum"] = 0

# %%
for p in optimizer.param_groups:
    p["lr"] = 0.0000005
