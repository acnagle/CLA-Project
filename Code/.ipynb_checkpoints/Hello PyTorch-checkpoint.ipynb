# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim

import matplotlib.pyplot as plt
# %matplotlib inline

X1 = torch.randn(1000, 50)
X2 = torch.randn(1000, 50) + 1.5
X = torch.cat([X1, X2], dim=0)
Y1 = torch.zeros(1000, 1)
Y2 = torch.ones(1000, 1)
Y = torch.cat([Y1, Y2], dim=0)
print(X.size())
print(Y.size())
# Out:
# torch.Size([2000, 50])
# torch.Size([2000, 1])

# %%
plt.scatter(X1[:, 0], X1[:, 1], color='b')
plt.scatter(X2[:, 0], X2[:, 1], color='r')

# %%
class Net(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(50, 50)
        self.relu1 = nn.ReLU()
        self.dout = nn.Dropout(0.2)
        self.fc2 = nn.Linear(50, 100)
        self.prelu = nn.PReLU(1)
        self.out = nn.Linear(100, 1)
        self.out_act = nn.Sigmoid()
        
    def forward(self, input_):
        a1 = self.fc1(input_)
        h1 = self.relu1(a1)
        dout = self.dout(h1)
        a2 = self.fc2(dout)
        h2 = self.prelu(a2)
        a3 = self.out(h2)
        y = self.out_act(a3)
        return y
    
net = Net()
opt = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999))
criterion = nn.BCELoss()

# %%
def train_epoch(model, opt, criterion, batch_size=50):
    model.train()
    losses = []
    for beg_i in range(0, X.size(0), batch_size):
        x_batch = X[beg_i:beg_i + batch_size, :]
        y_batch = Y[beg_i:beg_i + batch_size, :]
        x_batch = Variable(x_batch)
        y_batch = Variable(y_batch)

        opt.zero_grad()
        # (1) Forward
        y_hat = net(x_batch)
        # (2) Compute diff
        loss = criterion(y_hat, y_batch)
        # (3) Compute gradients
        loss.backward()
        # (4) update weights
        opt.step()        
        losses.append(loss.data.numpy())
        print(y_hat)
    return losses, y_hat

# %%
e_losses = []
num_epochs = 20
for e in range(num_epochs):
    losses, y = train_epoch(net, opt, criterion)
    e_losses += losses
plt.plot(e_losses)
print(y)
# Out:
# tensor([[0.5021],
#         [0.5356],
#         [0.4902],
#         [0.4976],
#         [0.5378],
#         [0.4593],
#         [0.4983],
#         [0.4967],
#         [0.4936],
#         [0.4984],
#         [0.5595],
#         [0.5063],
#         [0.4965],
#         [0.5178],
#         [0.5131],
#         [0.5096],
#         [0.5151],
#         [0.4787],
#         [0.5212],
#         [0.5020],
#         [0.5255],
#         [0.5181],
#         [0.5316],
#         [0.5030],
#         [0.5206],
#         [0.5462],
#         [0.5203],
#         [0.5253],
#         [0.4960],
#         [0.4802],
#         [0.5104],
#         [0.5399],
#         [0.5042],
#         [0.5167],
#         [0.5294],
#         [0.4836],
#         [0.5153],
#         [0.4991],
#         [0.5038],
#         [0.4977],
#         [0.5806],
#         [0.5092],
#         [0.5187],
#         [0.5343],
#         [0.5364],
#         [0.4989],
#         [0.5165],
#         [0.5217],
#         [0.4918],
#         [0.4966]], grad_fn=<SigmoidBackward>)
# tensor([[0.5165],
#         [0.5054],
#         [0.4869],
#         [0.5313],
#         [0.4551],
#         [0.4941],
#         [0.4873],
#         [0.5081],
#         [0.5307],
#         [0.4750],
#         [0.4926],
#         [0.5084],
#         [0.5173],
#         [0.4782],
#         [0.4884],
#         [0.5106],
#         [0.4805],
#         [0.5103],
#         [0.5247],
#         [0.5105],
#         [0.4960],
#         [0.5313],
#         [0.4487],
#         [0.4776],
#         [0.4879],
#         [0.5533],
#         [0.4965],
#         [0.4905],
#         [0.5176],
#         [0.4899],
#         [0.5193],
#         [0.4624],
#         [0.4963],
#         [0.5099],
#         [0.4925],
#         [0.5059],
#         [0.5000],
#         [0.5125],
#         [0.4807],
#         [0.5169],
#         [0.4904],
#         [0.5208],
#         [0.4691],
#         [0.4888],
#         [0.4651],
#         [0.4913],
#         [0.4874],
#         [0.4863],
#         [0.5055],
#         [0.4729]], grad_fn=<SigmoidBackward>)
# tensor([[0.4726],
#         [0.4788],
#         [0.5048],
#         [0.4914],
#         [0.4937],
#         [0.5296],
#         [0.4806],
#         [0.5051],
#         [0.4486],
#         [0.4777],
#         [0.4994],
#         [0.4798],
#         [0.5085],
#         [0.5085],
#         [0.4805],
#         [0.4891],
#         [0.4737],
#         [0.4949],
#         [0.4655],
#         [0.5105],
#         [0.5098],
#         [0.4882],
#         [0.4909],
#         [0.4535],
#         [0.4974],
#         [0.4780],
#         [0.4730],
#         [0.5074],
#         [0.4645],
#         [0.5046],
#         [0.5205],
#         [0.4958],
#         [0.4874],
#         [0.4655],
#         [0.4886],
#         [0.5013],
#         [0.4856],
#         [0.4975],
#         [0.4795],
#         [0.5054],
#         [0.4951],
#         [0.4795],
#         [0.5000],
#         [0.4811],
#         [0.4787],
#         [0.4662],
#         [0.4701],
#         [0.4579],
#         [0.4802],
#         [0.5006]], grad_fn=<SigmoidBackward>)
# tensor([[0.4808],
#         [0.4575],
#         [0.4805],
#         [0.4918],
#         [0.4763],
#         [0.4469],
#         [0.4582],
#         [0.4542],
#         [0.4981],
#         [0.4798],
#         [0.4875],
#         [0.5049],
#         [0.4770],
#         [0.4803],
#         [0.4732],
#         [0.4505],
#         [0.4768],
#         [0.4648],
#         [0.4654],
#         [0.4559],
#         [0.4154],
#         [0.4607],
#         [0.4709],
#         [0.4952],
#         [0.4724],
#         [0.4872],
#         [0.4853],
#         [0.4748],
#         [0.4907],
#         [0.4881],
#         [0.5124],
#         [0.5064],
#         [0.4761],
#         [0.4617],
#         [0.4556],
#         [0.4806],
#         [0.4602],
#         [0.4747],
#         [0.4938],
#         [0.4642],
#         [0.4788],
#         [0.4547],
#         [0.4400],
#         [0.4828],
#         [0.4686],
#         [0.4794],
#         [0.4689],
#         [0.4793],
#         [0.4795],
#         [0.4410]], grad_fn=<SigmoidBackward>)
# tensor([[0.4768],
#         [0.4539],
#         [0.4543],
#         [0.4772],
#         [0.4739],
#         [0.4661],
#         [0.4391],
#         [0.4737],
#         [0.4717],
#         [0.4380],
#         [0.4424],
#         [0.4677],
#         [0.4905],
#         [0.4263],
#         [0.4468],
#         [0.4606],
#         [0.4614],
#         [0.4431],
#         [0.4131],
#         [0.4598],
#         [0.4673],
#         [0.4698],
#         [0.4406],
#         [0.4761],
#         [0.4361],
#         [0.4642],
#         [0.4686],
#         [0.4161],
#         [0.4415],
#         [0.4556],
#         [0.4618],
#         [0.4584],
#         [0.4143],
#         [0.4885],
#         [0.4697],
#         [0.4616],
#         [0.4609],
#         [0.4764],
#         [0.5042],
#         [0.4700],
#         [0.4917],
#         [0.4552],
#         [0.4546],
#         [0.4411],
#         [0.4953],
#         [0.4427],
#         [0.4262],
#         [0.4271],
#         [0.4705],
#         [0.4585]], grad_fn=<SigmoidBackward>)
# tensor([[0.4171],
#         [0.4540],
#         [0.4266],
#         [0.4902],
#         [0.4410],
#         [0.4518],
#         [0.4274],
#         [0.4465],
#         [0.4498],
#         [0.4500],
#         [0.4515],
#         [0.4448],
#         [0.4388],
#         [0.4086],
#         [0.4116],
#         [0.4707],
#         [0.4534],
#         [0.4682],
#         [0.4893],
#         [0.4218],
#         [0.4470],
#         [0.4190],
#         [0.4557],
#         [0.4447],
#         [0.4117],
#         [0.4773],
#         [0.4808],
#         [0.4610],
#         [0.4736],
#         [0.4359],
#         [0.4571],
#         [0.4447],
#         [0.4429],
#         [0.4295],
#         [0.4415],
#         [0.4586],
#         [0.4594],
#         [0.4695],
#         [0.4424],
#         [0.4628],
#         [0.4647],
#         [0.4900],
#         [0.4376],
#         [0.4793],
#         [0.4319],
#         [0.4548],
#         [0.4584],
#         [0.4325],
#         [0.4631],
#         [0.4299]], grad_fn=<SigmoidBackward>)
# tensor([[0.4267],
#         [0.4421],
#         [0.4423],
#         [0.4246],
#         [0.4238],
#         [0.4549],
#         [0.4443],
#         [0.4139],
#         [0.4645],
#         [0.4403],
#         [0.4719],
#         [0.4370],
#         [0.4643],
#         [0.4517],
#         [0.4112],
#         [0.4315],
#         [0.4409],
#         [0.4390],
#         [0.4632],
#         [0.3948],
#         [0.4164],
#         [0.4160],
#         [0.4259],
#         [0.4462],
#         [0.4266],
#         [0.4352],
#         [0.4456],
#         [0.4008],
#         [0.4819],
#         [0.4494],
#         [0.4484],
#         [0.4307],
#         [0.4117],
#         [0.4287],
#         [0.4462],
#         [0.4394],
#         [0.3997],
#         [0.4141],
#         [0.4205],
#         [0.4581],
#         [0.4083],
#         [0.4360],
#         [0.4515],
#         [0.4383],
#         [0.4146],
#         [0.4108],
#         [0.4506],
#         [0.4249],
#         [0.4722],
#         [0.4474]], grad_fn=<SigmoidBackward>)
# tensor([[0.4456],
#         [0.4095],
#         [0.4026],
#         [0.4484],
#         [0.3874],
#         [0.3855],
#         [0.4253],
#         [0.4355],
#         [0.4246],
#         [0.4585],
#         [0.4220],
#         [0.4114],
#         [0.4186],
#         [0.4232],
#         [0.3628],
#         [0.4388],
#         [0.3756],
#         [0.4084],
#         [0.4027],
#         [0.4227],
#         [0.4181],
#         [0.4628],
#         [0.4381],
#         [0.4584],
#         [0.4251],
#         [0.4004],
#         [0.4197],
#         [0.4224],
#         [0.3954],
#         [0.4397],
#         [0.4152],
#         [0.4140],
#         [0.4380],
#         [0.4434],
#         [0.4574],
#         [0.4563],
#         [0.4470],
#         [0.4104],
#         [0.4244],
#         [0.4355],
#         [0.4116],
#         [0.4277],
#         [0.4339],
#         [0.4334],
#         [0.4513],
#         [0.4316],
#         [0.4638],
#         [0.4664],
#         [0.4408],
#         [0.3994]], grad_fn=<SigmoidBackward>)
# tensor([[0.4203],
#         [0.4007],
#         [0.4083],
#         [0.3976],
#         [0.3392],
#         [0.4685],
#         [0.3604],
#         [0.3995],
#         [0.4150],
#         [0.4535],
#         [0.3948],
#         [0.4242],
#         [0.4177],
#         [0.4414],
#         [0.4232],
#         [0.3877],
#         [0.4442],
#         [0.4104],
#         [0.4172],
#         [0.4318],
#         [0.4135],
#         [0.3841],
#         [0.4228],
#         [0.4288],
#         [0.4297],
#         [0.4673],
#         [0.4184],
#         [0.4354],
#         [0.4155],
#         [0.3690],
#         [0.4140],
#         [0.3998],
#         [0.4224],
#         [0.3594],
#         [0.3761],
#         [0.3647],
#         [0.4006],
#         [0.4118],
#         [0.4347],
#         [0.3855],
#         [0.4002],
#         [0.3996],
#         [0.4479],
#         [0.3788],
#         [0.4067],
#         [0.3779],
#         [0.4611],
#         [0.4027],
#         [0.4282],
#         [0.4270]], grad_fn=<SigmoidBackward>)
# tensor([[0.3998],
#         [0.3867],
#         [0.4691],
#         [0.3852],
#         [0.4193],
#         [0.4299],
#         [0.4283],
#         [0.3691],
#         [0.4391],
#         [0.3733],
#         [0.4209],
#         [0.3721],
#         [0.4283],
#         [0.3997],
#         [0.4060],
#         [0.3804],
#         [0.3859],
#         [0.4039],
#         [0.4062],
#         [0.4072],
#         [0.3505],
#         [0.4173],
#         [0.4385],
#         [0.4119],
#         [0.4207],
#         [0.3832],
#         [0.4596],
#         [0.4175],
#         [0.4434],
#         [0.3615],
#         [0.4108],
#         [0.4465],
#         [0.3564],
#         [0.3912],
#         [0.4401],
#         [0.4094],
#         [0.4222],
#         [0.4341],
#         [0.4279],
#         [0.3924],
#         [0.4020],
#         [0.4312],
#         [0.4041],
#         [0.3729],
#         [0.3324],
#         [0.4007],
#         [0.3650],
#         [0.3355],
#         [0.3786],
#         [0.3994]], grad_fn=<SigmoidBackward>)
# tensor([[0.4120],
#         [0.3998],
#         [0.3455],
#         [0.4113],
#         [0.3983],
#         [0.3965],
#         [0.3470],
#         [0.4218],
#         [0.3521],
#         [0.3796],
#         [0.3878],
#         [0.4307],
#         [0.3516],
#         [0.3583],
#         [0.3402],
#         [0.3806],
#         [0.4196],
#         [0.3918],
#         [0.4026],
#         [0.3376],
#         [0.3895],
#         [0.3895],
#         [0.4061],
#         [0.2775],
#         [0.4187],
#         [0.3376],
#         [0.3315],
#         [0.4081],
#         [0.4220],
#         [0.3153],
#         [0.3934],
#         [0.3857],
#         [0.3818],
#         [0.3961],
#         [0.3174],
#         [0.3793],
#         [0.3662],
#         [0.3711],
#         [0.3551],
#         [0.3893],
#         [0.4040],
#         [0.3983],
#         [0.3876],
#         [0.3440],
#         [0.4545],
#         [0.3529],
#         [0.3871],
#         [0.3962],
#         [0.4140],
#         [0.4099]], grad_fn=<SigmoidBackward>)
# tensor([[0.4083],
#         [0.3482],
#         [0.3256],
#         [0.2641],
#         [0.4185],
#         [0.3299],
#         [0.3958],
#         [0.3131],
#         [0.3999],
#         [0.3647],
#         [0.4089],
#         [0.3782],
#         [0.3428],
#         [0.3477],
#         [0.3522],
#         [0.3687],
#         [0.3867],
#         [0.3619],
#         [0.3584],
#         [0.3295],
#         [0.3305],
#         [0.3868],
#         [0.4111],
#         [0.4362],
#         [0.3658],
#         [0.3567],
#         [0.4017],
#         [0.3148],
#         [0.3443],
#         [0.3769],
#         [0.3655],
#         [0.3700],
#         [0.4054],
#         [0.4074],
#         [0.3426],
#         [0.3725],
#         [0.4031],
#         [0.3206],
#         [0.4054],
#         [0.4091],
#         [0.3601],
#         [0.4083],
#         [0.2636],
#         [0.3707],
#         [0.3843],
#         [0.4076],
#         [0.3818],
#         [0.2964],
#         [0.3867],
#         [0.3560]], grad_fn=<SigmoidBackward>)
# tensor([[0.3324],
#         [0.3494],
#         [0.3072],
#         [0.3767],
#         [0.3895],
#         [0.3851],
#         [0.4031],
#         [0.3628],
#         [0.3557],
#         [0.3505],
#         [0.3631],
#         [0.3857],
#         [0.3786],
#         [0.4247],
#         [0.3853],
#         [0.3702],
#         [0.3813],
#         [0.3682],
#         [0.4326],
#         [0.3712],
#         [0.3228],
#         [0.3821],
#         [0.3411],
#         [0.3261],
#         [0.3671],
#         [0.2748],
#         [0.3784],
#         [0.4027],
#         [0.3917],
#         [0.3726],
#         [0.3068],
#         [0.3591],
#         [0.2737],
#         [0.3972],
#         [0.3202],
#         [0.4091],
#         [0.3187],
#         [0.2848],
#         [0.3358],
#         [0.3577],
#         [0.3520],
#         [0.3263],
#         [0.3011],
#         [0.3099],
#         [0.3696],
#         [0.3611],
#         [0.3249],
#         [0.3607],
#         [0.3501],
#         [0.3537]], grad_fn=<SigmoidBackward>)
# tensor([[0.3427],
#         [0.3776],
#         [0.3384],
#         [0.3592],
#         [0.3653],
#         [0.3275],
#         [0.3019],
#         [0.3013],
#         [0.3367],
#         [0.3789],
#         [0.3555],
#         [0.3313],
#         [0.2947],
#         [0.2545],
#         [0.3873],
#         [0.2757],
#         [0.3800],
#         [0.3624],
#         [0.4037],
#         [0.3895],
#         [0.3998],
#         [0.3709],
#         [0.4478],
#         [0.3262],
#         [0.3266],
#         [0.3542],
#         [0.3656],
#         [0.3753],
#         [0.3732],
#         [0.3931],
#         [0.3155],
#         [0.3204],
#         [0.3579],
#         [0.3091],
#         [0.3799],
#         [0.3286],
#         [0.3332],
#         [0.3550],
#         [0.3772],
#         [0.2915],
#         [0.3756],
#         [0.3686],
#         [0.4106],
#         [0.3183],
#         [0.3546],
#         [0.3755],
#         [0.3201],
#         [0.3474],
#         [0.3655],
#         [0.3600]], grad_fn=<SigmoidBackward>)
# tensor([[0.3146],
#         [0.2685],
#         [0.3715],
#         [0.3149],
#         [0.3611],
#         [0.3971],
#         [0.3531],
#         [0.4041],
#         [0.3847],
#         [0.3100],
#         [0.3203],
#         [0.3237],
#         [0.3259],
#         [0.3533],
#         [0.4132],
#         [0.3829],
#         [0.3308],
#         [0.3254],
#         [0.3871],
#         [0.3964],
#         [0.3244],
#         [0.3484],
#         [0.3679],
#         [0.2667],
#         [0.3981],
#         [0.2077],
#         [0.2915],
#         [0.3228],
#         [0.3543],
#         [0.3193],
#         [0.2751],
#         [0.4074],
#         [0.2874],
#         [0.3287],
#         [0.3385],
#         [0.4087],
#         [0.3113],
#         [0.2822],
#         [0.4025],
#         [0.3187],
#         [0.3814],
#         [0.3199],
#         [0.2751],
#         [0.4057],
#         [0.3915],
#         [0.3683],
#         [0.3448],
#         [0.3456],
#         [0.3954],
#         [0.3513]], grad_fn=<SigmoidBackward>)
# tensor([[0.3743],
#         [0.3070],
#         [0.3397],
#         [0.2913],
#         [0.3990],
#         [0.2579],
#         [0.3604],
#         [0.2262],
#         [0.2997],
#         [0.2755],
#         [0.2299],
#         [0.1868],
#         [0.2603],
#         [0.3126],
#         [0.3674],
#         [0.3522],
#         [0.2618],
#         [0.2800],
#         [0.3287],
#         [0.3231],
#         [0.3772],
#         [0.3010],
#         [0.1891],
#         [0.3359],
#         [0.3171],
#         [0.2736],
#         [0.2534],
#         [0.3755],
#         [0.3008],
#         [0.3879],
#         [0.2854],
#         [0.3462],
#         [0.3466],
#         [0.3772],
#         [0.2512],
#         [0.2636],
#         [0.3064],
#         [0.3584],
#         [0.3820],
#         [0.3595],
#         [0.2853],
#         [0.3228],
#         [0.3750],
#         [0.2564],
#         [0.2361],
#         [0.3352],
#         [0.3572],
#         [0.3026],
#         [0.2745],
#         [0.2973]], grad_fn=<SigmoidBackward>)
# tensor([[0.3789],
#         [0.3264],
#         [0.3090],
#         [0.2400],
#         [0.3186],
#         [0.3361],
#         [0.3078],
#         [0.3596],
#         [0.2773],
#         [0.3375],
#         [0.3602],
#         [0.2481],
#         [0.3220],
#         [0.2178],
#         [0.3058],
#         [0.3094],
#         [0.3558],
#         [0.2684],
#         [0.3340],
#         [0.3063],
#         [0.3371],
#         [0.3374],
#         [0.2781],
#         [0.3548],
#         [0.3654],
#         [0.2327],
#         [0.3390],
#         [0.3063],
#         [0.3575],
#         [0.3359],
#         [0.2898],
#         [0.3090],
#         [0.2887],
#         [0.3117],
#         [0.3512],
#         [0.3365],
#         [0.3073],
#         [0.3120],
#         [0.3365],
#         [0.3336],
#         [0.2907],
#         [0.3461],
#         [0.2330],
#         [0.2560],
#         [0.3311],
#         [0.2977],
#         [0.3251],
#         [0.3127],
#         [0.2734],
#         [0.3467]], grad_fn=<SigmoidBackward>)
# tensor([[0.3206],
#         [0.2503],
#         [0.2771],
#         [0.2164],
#         [0.2897],
#         [0.3025],
#         [0.3531],
#         [0.1954],
#         [0.2819],
#         [0.2435],
#         [0.4033],
#         [0.3595],
#         [0.2001],
#         [0.2911],
#         [0.2712],
#         [0.3834],
#         [0.3234],
#         [0.3355],
#         [0.3044],
#         [0.2315],
#         [0.2974],
#         [0.3149],
#         [0.2708],
#         [0.3193],
#         [0.3211],
#         [0.3371],
#         [0.2968],
#         [0.2677],
#         [0.4154],
#         [0.3557],
#         [0.3313],
#         [0.2426],
#         [0.3014],
#         [0.3695],
#         [0.3407],
#         [0.3495],
#         [0.2589],
#         [0.2785],
#         [0.3592],
#         [0.3338],
#         [0.2693],
#         [0.2782],
#         [0.2755],
#         [0.2298],
#         [0.3272],
#         [0.2596],
#         [0.2235],
#         [0.2670],
#         [0.3174],
#         [0.2557]], grad_fn=<SigmoidBackward>)
# tensor([[0.2798],
#         [0.3283],
#         [0.2886],
#         [0.3045],
#         [0.2979],
#         [0.3180],
#         [0.2786],
#         [0.3172],
#         [0.3333],
#         [0.3243],
#         [0.2639],
#         [0.2545],
#         [0.3247],
#         [0.2567],
#         [0.2960],
#         [0.3154],
#         [0.2905],
#         [0.3255],
#         [0.3608],
#         [0.3278],
#         [0.2880],
#         [0.2813],
#         [0.2767],
#         [0.2575],
#         [0.2528],
#         [0.3265],
#         [0.1455],
#         [0.2597],
#         [0.2827],
#         [0.3243],
#         [0.2687],
#         [0.3144],
#         [0.2731],
#         [0.2904],
#         [0.2930],
#         [0.2456],
#         [0.1961],
#         [0.2313],
#         [0.2629],
#         [0.2833],
#         [0.2837],
#         [0.2815],
#         [0.2957],
#         [0.2033],
#         [0.3053],
#         [0.3086],
#         [0.2903],
#         [0.2479],
#         [0.3251],
#         [0.2862]], grad_fn=<SigmoidBackward>)
# tensor([[0.1647],
#         [0.2531],
#         [0.2611],
#         [0.2548],
#         [0.1945],
#         [0.1874],
#         [0.1751],
#         [0.2483],
#         [0.2692],
#         [0.3818],
#         [0.3102],
#         [0.3299],
#         [0.3120],
#         [0.2620],
#         [0.2290],
#         [0.1678],
#         [0.2150],
#         [0.2974],
#         [0.3301],
#         [0.3237],
#         [0.3008],
#         [0.2662],
#         [0.2752],
#         [0.3114],
#         [0.2970],
#         [0.2310],
#         [0.3471],
#         [0.3103],
#         [0.2344],
#         [0.2554],
#         [0.2492],
#         [0.2783],
#         [0.2970],
#         [0.2576],
#         [0.3359],
#         [0.4229],
#         [0.2526],
#         [0.2929],
#         [0.1974],
#         [0.3244],
#         [0.1975],
#         [0.2616],
#         [0.2763],
#         [0.2438],
#         [0.3186],
#         [0.2004],
#         [0.2234],
#         [0.2932],
#         [0.3189],
#         [0.3450]], grad_fn=<SigmoidBackward>)
# tensor([[0.1491],
#         [0.1171],
#         [0.1003],
#         [0.1013],
#         [0.1669],
#         [0.1096],
#         [0.1576],
#         [0.1729],
#         [0.0952],
#         [0.1353],
#         [0.1137],
#         [0.0938],
#         [0.1179],
#         [0.1807],
#         [0.1187],
#         [0.0938],
#         [0.1196],
#         [0.1671],
#         [0.1616],
#         [0.1589],
#         [0.0557],
#         [0.1382],
#         [0.0872],
#         [0.2373],
#         [0.0863],
#         [0.1316],
#         [0.1107],
#         [0.0673],
#         [0.1163],
#         [0.1895],
#         [0.1443],
#         [0.1535],
#         [0.1288],
#         [0.1478],
#         [0.1230],
#         [0.0995],
#         [0.1072],
#         [0.1278],
#         [0.0673],
#         [0.1117],
#         [0.0925],
#         [0.1468],
#         [0.1468],
#         [0.1593],
#         [0.1866],
#         [0.1536],
#         [0.2054],
#         [0.0672],
#         [0.2086],
#         [0.0872]], grad_fn=<SigmoidBackward>)
# tensor([[0.1900],
#         [0.1539],
#         [0.0765],
#         [0.1905],
#         [0.1398],
#         [0.1571],
#         [0.0678],
#         [0.1326],
#         [0.1862],
#         [0.1349],
#         [0.2417],
#         [0.1003],
#         [0.1088],
#         [0.1575],
#         [0.1918],
#         [0.1861],
#         [0.0953],
#         [0.1711],
#         [0.0870],
#         [0.0630],
#         [0.0705],
#         [0.1626],
#         [0.1079],
#         [0.1606],
#         [0.0644],
#         [0.2051],
#         [0.1131],
#         [0.1504],
#         [0.1289],
#         [0.1641],
#         [0.2280],
#         [0.1525],
#         [0.1801],
#         [0.1092],
#         [0.2152],
#         [0.1310],
#         [0.0891],
#         [0.1635],
#         [0.1479],
#         [0.0943],
#         [0.1384],
#         [0.1105],
#         [0.1317],
#         [0.1721],
#         [0.1577],
#         [0.1603],
#         [0.1355],
#         [0.1323],
#         [0.2158],
#         [0.1876]], grad_fn=<SigmoidBackward>)
# tensor([[0.1526],
#         [0.1897],
#         [0.1392],
#         [0.1962],
#         [0.1592],
#         [0.1769],
#         [0.0970],
#         [0.2038],
#         [0.1820],
#         [0.1252],
#         [0.1569],
#         [0.1517],
#         [0.1352],
#         [0.1198],
#         [0.1269],
#         [0.1737],
#         [0.1901],
#         [0.1336],
#         [0.1879],
#         [0.0985],
#         [0.2240],
#         [0.1303],
#         [0.1929],
#         [0.1841],
#         [0.1055],
#         [0.2287],
#         [0.1089],
#         [0.2513],
#         [0.2196],
#         [0.2113],
#         [0.0912],
#         [0.1037],
#         [0.1186],
#         [0.2343],
#         [0.2357],
#         [0.1610],
#         [0.2130],
#         [0.1742],
#         [0.1709],
#         [0.1507],
#         [0.1115],
#         [0.2518],
#         [0.1158],
#         [0.1682],
#         [0.1417],
#         [0.0759],
#         [0.1422],
#         [0.1524],
#         [0.1248],
#         [0.1933]], grad_fn=<SigmoidBackward>)
# tensor([[0.1569],
#         [0.1902],
#         [0.1894],
#         [0.1435],
#         [0.1944],
#         [0.1403],
#         [0.2273],
#         [0.2179],
#         [0.2070],
#         [0.2182],
#         [0.2188],
#         [0.2089],
#         [0.1432],
#         [0.3205],
#         [0.2329],
#         [0.1076],
#         [0.1828],
#         [0.2012],
#         [0.2729],
#         [0.1818],
#         [0.1465],
#         [0.2079],
#         [0.2059],
#         [0.2263],
#         [0.1447],
#         [0.1864],
#         [0.1128],
#         [0.1560],
#         [0.1857],
#         [0.1250],
#         [0.1290],
#         [0.1164],
#         [0.1763],
#         [0.2466],
#         [0.1946],
#         [0.1568],
#         [0.1322],
#         [0.1205],
#         [0.2455],
#         [0.1755],
#         [0.1729],
#         [0.0810],
#         [0.1438],
#         [0.2404],
#         [0.2259],
#         [0.1589],
#         [0.2376],
#         [0.2228],
#         [0.1880],
#         [0.1847]], grad_fn=<SigmoidBackward>)
# tensor([[0.2158],
#         [0.2015],
#         [0.1920],
#         [0.2010],
#         [0.2455],
#         [0.1886],
#         [0.1215],
#         [0.2242],
#         [0.1344],
#         [0.0965],
#         [0.2673],
#         [0.1254],
#         [0.2220],
#         [0.1949],
#         [0.2499],
#         [0.2166],
#         [0.2061],
#         [0.2415],
#         [0.1494],
#         [0.2190],
#         [0.1552],
#         [0.1998],
#         [0.1110],
#         [0.2050],
#         [0.1770],
#         [0.1610],
#         [0.1884],
#         [0.1625],
#         [0.2092],
#         [0.3310],
#         [0.1978],
#         [0.1932],
#         [0.1601],
#         [0.1380],
#         [0.2209],
#         [0.2030],
#         [0.2456],
#         [0.2412],
#         [0.2113],
#         [0.2037],
#         [0.2531],
#         [0.2413],
#         [0.2177],
#         [0.1693],
#         [0.2593],
#         [0.2432],
#         [0.1800],
#         [0.2170],
#         [0.2634],
#         [0.2029]], grad_fn=<SigmoidBackward>)
# tensor([[0.3218],
#         [0.2404],
#         [0.1813],
#         [0.3450],
#         [0.2781],
#         [0.3158],
#         [0.2185],
#         [0.2029],
#         [0.2310],
#         [0.2198],
#         [0.2629],
#         [0.2270],
#         [0.1821],
#         [0.1897],
#         [0.2767],
#         [0.1504],
#         [0.2762],
#         [0.3238],
#         [0.2332],
#         [0.1395],
#         [0.1958],
#         [0.2396],
#         [0.2443],
#         [0.3154],
#         [0.1080],
#         [0.1779],
#         [0.1442],
#         [0.2701],
#         [0.2078],
#         [0.1577],
#         [0.2132],
#         [0.2148],
#         [0.2270],
#         [0.1973],
#         [0.2574],
#         [0.2061],
#         [0.1820],
#         [0.2583],
#         [0.2346],
#         [0.2802],
#         [0.2136],
#         [0.2621],
#         [0.2328],
#         [0.2386],
#         [0.2235],
#         [0.2250],
#         [0.2032],
#         [0.2180],
#         [0.2329],
#         [0.2091]], grad_fn=<SigmoidBackward>)
# tensor([[0.2264],
#         [0.2977],
#         [0.2119],
#         [0.1827],
#         [0.1935],
#         [0.2700],
#         [0.2792],
#         [0.2318],
#         [0.2444],
#         [0.2512],
#         [0.2233],
#         [0.3062],
#         [0.2635],
#         [0.2850],
#         [0.2180],
#         [0.2170],
#         [0.1655],
#         [0.2200],
#         [0.2203],
#         [0.1833],
#         [0.1822],
#         [0.1872],
#         [0.2189],
#         [0.3175],
#         [0.1684],
#         [0.2914],
#         [0.2575],
#         [0.2621],
#         [0.2524],
#         [0.2573],
#         [0.2052],
#         [0.2342],
#         [0.2734],
#         [0.2737],
#         [0.3122],
#         [0.2477],
#         [0.2278],
#         [0.2261],
#         [0.2602],
#         [0.2944],
#         [0.1876],
#         [0.2179],
#         [0.2574],
#         [0.2115],
#         [0.2446],
#         [0.1945],
#         [0.2253],
#         [0.2561],
#         [0.1936],
#         [0.3139]], grad_fn=<SigmoidBackward>)
# tensor([[0.2731],
#         [0.3780],
#         [0.2567],
#         [0.2506],
#         [0.2445],
#         [0.2431],
#         [0.3342],
#         [0.2730],
#         [0.2707],
#         [0.3052],
#         [0.4026],
#         [0.2879],
#         [0.3622],
#         [0.2983],
#         [0.3241],
#         [0.2313],
#         [0.1935],
#         [0.2378],
#         [0.2086],
#         [0.2587],
#         [0.2592],
#         [0.3054],
#         [0.2929],
#         [0.2963],
#         [0.2234],
#         [0.2140],
#         [0.2544],
#         [0.3507],
#         [0.2830],
#         [0.3496],
#         [0.3224],
#         [0.3225],
#         [0.2255],
#         [0.3574],
#         [0.2577],
#         [0.2962],
#         [0.2299],
#         [0.3022],
#         [0.3358],
#         [0.3493],
#         [0.2351],
#         [0.3547],
#         [0.2403],
#         [0.3115],
#         [0.2487],
#         [0.2903],
#         [0.3318],
#         [0.2549],
#         [0.2644],
#         [0.2451]], grad_fn=<SigmoidBackward>)
# tensor([[0.3899],
#         [0.3072],
#         [0.2486],
#         [0.3366],
#         [0.2550],
#         [0.2373],
#         [0.3271],
#         [0.3427],
#         [0.3218],
#         [0.2949],
#         [0.3366],
#         [0.2701],
#         [0.3127],
#         [0.2776],
#         [0.3346],
#         [0.3263],
#         [0.4026],
#         [0.3192],
#         [0.3712],
#         [0.2952],
#         [0.4346],
#         [0.3630],
#         [0.2778],
#         [0.3030],
#         [0.3183],
#         [0.2893],
#         [0.3626],
#         [0.3805],
#         [0.3006],
#         [0.2883],
#         [0.3089],
#         [0.2994],
#         [0.2466],
#         [0.3213],
#         [0.3242],
#         [0.2603],
#         [0.2738],
#         [0.3198],
#         [0.3311],
#         [0.3358],
#         [0.3120],
#         [0.2778],
#         [0.2889],
#         [0.3577],
#         [0.3007],
#         [0.3219],
#         [0.3763],
#         [0.2926],
#         [0.3106],
#         [0.2531]], grad_fn=<SigmoidBackward>)
# tensor([[0.3528],
#         [0.2741],
#         [0.3327],
#         [0.3723],
#         [0.2796],
#         [0.3740],
#         [0.3561],
#         [0.3659],
#         [0.3273],
#         [0.3218],
#         [0.3638],
#         [0.3522],
#         [0.3283],
#         [0.3386],
#         [0.3684],
#         [0.2597],
#         [0.3569],
#         [0.3314],
#         [0.3050],
#         [0.3215],
#         [0.2317],
#         [0.4025],
#         [0.3870],
#         [0.3792],
#         [0.3463],
#         [0.3150],
#         [0.3403],
#         [0.3873],
#         [0.3479],
#         [0.3624],
#         [0.2709],
#         [0.3547],
#         [0.3251],
#         [0.3290],
#         [0.2649],
#         [0.3645],
#         [0.3796],
#         [0.3110],
#         [0.4081],
#         [0.3138],
#         [0.3377],
#         [0.3185],
#         [0.3864],
#         [0.3377],
#         [0.3496],
#         [0.3785],
#         [0.3701],
#         [0.3037],
#         [0.2879],
#         [0.3690]], grad_fn=<SigmoidBackward>)
# tensor([[0.3781],
#         [0.3917],
#         [0.3146],
#         [0.3876],
#         [0.4048],
#         [0.3722],
#         [0.3463],
#         [0.4229],
#         [0.4141],
#         [0.3510],
#         [0.3476],
#         [0.3926],
#         [0.3999],
#         [0.3469],
#         [0.3779],
#         [0.3433],
#         [0.3117],
#         [0.3758],
#         [0.3249],
#         [0.3449],
#         [0.3820],
#         [0.3522],
#         [0.4146],
#         [0.3086],
#         [0.3765],
#         [0.4030],
#         [0.3718],
#         [0.3608],
#         [0.3785],
#         [0.3848],
#         [0.3718],
#         [0.3809],
#         [0.4145],
#         [0.4062],
#         [0.3612],
#         [0.3303],
#         [0.3723],
#         [0.4296],
#         [0.3660],
#         [0.3405],
#         [0.3277],
#         [0.3668],
#         [0.3249],
#         [0.3708],
#         [0.3639],
#         [0.3830],
#         [0.3864],
#         [0.2969],
#         [0.3782],
#         [0.3600]], grad_fn=<SigmoidBackward>)
# tensor([[0.3866],
#         [0.3655],
#         [0.3397],
#         [0.4438],
#         [0.3709],
#         [0.3503],
#         [0.3509],
#         [0.3694],
#         [0.4341],
#         [0.3742],
#         [0.3861],
#         [0.3633],
#         [0.4326],
#         [0.3743],
#         [0.3993],
#         [0.3885],
#         [0.3669],
#         [0.3824],
#         [0.3767],
#         [0.4315],
#         [0.3723],
#         [0.3888],
#         [0.4026],
#         [0.4106],
#         [0.3341],
#         [0.3651],
#         [0.4264],
#         [0.3525],
#         [0.3961],
#         [0.4397],
#         [0.3900],
#         [0.4089],
#         [0.3773],
#         [0.3903],
#         [0.3907],
#         [0.3847],
#         [0.4031],
#         [0.3634],
#         [0.4004],
#         [0.3917],
#         [0.4258],
#         [0.3719],
#         [0.4138],
#         [0.3705],
#         [0.3594],
#         [0.3868],
#         [0.4352],
#         [0.3874],
#         [0.3862],
#         [0.4240]], grad_fn=<SigmoidBackward>)
# tensor([[0.3990],
#         [0.4075],
#         [0.4342],
#         [0.3538],
#         [0.3991],
#         [0.3844],
#         [0.3457],
#         [0.3733],
#         [0.4352],
#         [0.4106],
#         [0.4133],
#         [0.3914],
#         [0.4165],
#         [0.4182],
#         [0.3438],
#         [0.4094],
#         [0.3766],
#         [0.3974],
#         [0.4345],
#         [0.4097],
#         [0.3605],
#         [0.4280],
#         [0.3823],
#         [0.3865],
#         [0.4373],
#         [0.4102],
#         [0.4512],
#         [0.3991],
#         [0.3680],
#         [0.3867],
#         [0.4023],
#         [0.3826],
#         [0.4133],
#         [0.4341],
#         [0.4300],
#         [0.3882],
#         [0.4065],
#         [0.4054],
#         [0.3907],
#         [0.4090],
#         [0.4333],
#         [0.4025],
#         [0.4437],
#         [0.4394],
#         [0.3994],
#         [0.3906],
#         [0.3966],
#         [0.4099],
#         [0.4611],
#         [0.3919]], grad_fn=<SigmoidBackward>)
# tensor([[0.3939],
#         [0.4598],
#         [0.4523],
#         [0.4349],
#         [0.4546],
#         [0.4190],
#         [0.4014],
#         [0.4293],
#         [0.4156],
#         [0.4161],
#         [0.3847],
#         [0.3964],
#         [0.4241],
#         [0.4155],
#         [0.3970],
#         [0.4315],
#         [0.4220],
#         [0.4509],
#         [0.3309],
#         [0.4576],
#         [0.3827],
#         [0.4227],
#         [0.4046],
#         [0.4458],
#         [0.4101],
#         [0.3960],
#         [0.4194],
#         [0.4228],
#         [0.4157],
#         [0.3961],
#         [0.4349],
#         [0.4099],
#         [0.3871],
#         [0.4700],
#         [0.4230],
#         [0.4047],
#         [0.4296],
#         [0.4372],
#         [0.4244],
#         [0.4339],
#         [0.4223],
#         [0.4373],
#         [0.4096],
#         [0.3998],
#         [0.4158],
#         [0.4394],
#         [0.3890],
#         [0.4348],
#         [0.4217],
#         [0.4262]], grad_fn=<SigmoidBackward>)
# tensor([[0.4397],
#         [0.4496],
#         [0.4201],
#         [0.4180],
#         [0.4255],
#         [0.4372],
#         [0.4099],
#         [0.4307],
#         [0.4839],
#         [0.4294],
#         [0.4387],
#         [0.4519],
#         [0.4713],
#         [0.4227],
#         [0.4257],
#         [0.4366],
#         [0.4394],
#         [0.4258],
#         [0.4487],
#         [0.3872],
#         [0.4531],
#         [0.4265],
#         [0.4206],
#         [0.4593],
#         [0.4152],
#         [0.4298],
#         [0.4484],
#         [0.4317],
#         [0.4453],
#         [0.4280],
#         [0.4476],
#         [0.4137],
#         [0.4312],
#         [0.4631],
#         [0.4395],
#         [0.4496],
#         [0.3973],
#         [0.4609],
#         [0.3528],
#         [0.4582],
#         [0.4151],
#         [0.4271],
#         [0.4332],
#         [0.4228],
#         [0.4297],
#         [0.4529],
#         [0.4592],
#         [0.4265],
#         [0.4640],
#         [0.4037]], grad_fn=<SigmoidBackward>)
# tensor([[0.4528],
#         [0.4433],
#         [0.4411],
#         [0.4883],
#         [0.4574],
#         [0.4626],
#         [0.4753],
#         [0.4355],
#         [0.4282],
#         [0.4502],
#         [0.4777],
#         [0.4833],
#         [0.4311],
#         [0.4431],
#         [0.4542],
#         [0.4632],
#         [0.4785],
#         [0.4727],
#         [0.4681],
#         [0.4589],
#         [0.4764],
#         [0.4739],
#         [0.4618],
#         [0.4604],
#         [0.4644],
#         [0.4623],
#         [0.4333],
#         [0.4427],
#         [0.4522],
#         [0.4634],
#         [0.4387],
#         [0.4358],
#         [0.4399],
#         [0.4303],
#         [0.4415],
#         [0.4207],
#         [0.4394],
#         [0.4771],
#         [0.4747],
#         [0.4579],
#         [0.4370],
#         [0.4546],
#         [0.4505],
#         [0.4482],
#         [0.4320],
#         [0.4524],
#         [0.4615],
#         [0.4649],
#         [0.4710],
#         [0.4660]], grad_fn=<SigmoidBackward>)
# tensor([[0.4449],
#         [0.4606],
#         [0.4661],
#         [0.4799],
#         [0.4793],
#         [0.4436],
#         [0.4562],
#         [0.4603],
#         [0.4625],
#         [0.4731],
#         [0.4468],
#         [0.4579],
#         [0.4840],
#         [0.4695],
#         [0.4707],
#         [0.4404],
#         [0.4572],
#         [0.4378],
#         [0.4593],
#         [0.4664],
#         [0.4441],
#         [0.4457],
#         [0.4831],
#         [0.4677],
#         [0.4483],
#         [0.4585],
#         [0.3904],
#         [0.4613],
#         [0.4505],
#         [0.4603],
#         [0.4304],
#         [0.4465],
#         [0.4693],
#         [0.4411],
#         [0.4719],
#         [0.4686],
#         [0.4511],
#         [0.4749],
#         [0.4341],
#         [0.4508],
#         [0.4671],
#         [0.4588],
#         [0.4978],
#         [0.4859],
#         [0.4812],
#         [0.4557],
#         [0.4610],
#         [0.4642],
#         [0.4641],
#         [0.4707]], grad_fn=<SigmoidBackward>)
# tensor([[0.4663],
#         [0.4835],
#         [0.4469],
#         [0.4689],
#         [0.4956],
#         [0.4991],
#         [0.4772],
#         [0.4866],
#         [0.4955],
#         [0.4643],
#         [0.4896],
#         [0.4886],
#         [0.4675],
#         [0.4783],
#         [0.4873],
#         [0.5052],
#         [0.4527],
#         [0.4532],
#         [0.4818],
#         [0.4710],
#         [0.4778],
#         [0.4838],
#         [0.4654],
#         [0.4668],
#         [0.4887],
#         [0.4433],
#         [0.4997],
#         [0.4880],
#         [0.4763],
#         [0.4753],
#         [0.4863],
#         [0.4192],
#         [0.4787],
#         [0.4762],
#         [0.4711],
#         [0.4857],
#         [0.4513],
#         [0.4693],
#         [0.4790],
#         [0.4786],
#         [0.4805],
#         [0.4719],
#         [0.4482],
#         [0.4534],
#         [0.4852],
#         [0.4720],
#         [0.4451],
#         [0.5005],
#         [0.4793],
#         [0.4670]], grad_fn=<SigmoidBackward>)
# tensor([[0.5011],
#         [0.5016],
#         [0.4790],
#         [0.4799],
#         [0.4899],
#         [0.4721],
#         [0.5024],
#         [0.4847],
#         [0.4799],
#         [0.4830],
#         [0.4942],
#         [0.4651],
#         [0.4697],
#         [0.4959],
#         [0.4935],
#         [0.4921],
#         [0.4778],
#         [0.4554],
#         [0.4783],
#         [0.4721],
#         [0.4854],
#         [0.4964],
#         [0.4889],
#         [0.4749],
#         [0.4661],
#         [0.4858],
#         [0.4880],
#         [0.4755],
#         [0.4687],
#         [0.4943],
#         [0.4570],
#         [0.4622],
#         [0.4722],
#         [0.4896],
#         [0.4766],
#         [0.4647],
#         [0.4565],
#         [0.4611],
#         [0.4843],
#         [0.5035],
#         [0.4946],
#         [0.4914],
#         [0.4949],
#         [0.5009],
#         [0.4833],
#         [0.5000],
#         [0.4811],
#         [0.4541],
#         [0.4822],
#         [0.4885]], grad_fn=<SigmoidBackward>)
# tensor([[0.4623],
#         [0.4936],
#         [0.5080],
#         [0.5075],
#         [0.4867],
#         [0.4772],
#         [0.5116],
#         [0.4835],
#         [0.4883],
#         [0.4988],
#         [0.5151],
#         [0.4905],
#         [0.4879],
#         [0.4932],
#         [0.5137],
#         [0.5018],
#         [0.5066],
#         [0.4941],
#         [0.4958],
#         [0.4774],
#         [0.4596],
#         [0.4813],
#         [0.5081],
#         [0.5119],
#         [0.4836],
#         [0.4731],
#         [0.4991],
#         [0.4944],
#         [0.4813],
#         [0.5118],
#         [0.4977],
#         [0.4887],
#         [0.5107],
#         [0.4736],
#         [0.5075],
#         [0.4979],
#         [0.5023],
#         [0.4801],
#         [0.5032],
#         [0.4956],
#         [0.4846],
#         [0.4999],
#         [0.4804],
#         [0.4800],
#         [0.4572],
#         [0.5070],
#         [0.4959],
#         [0.4403],
#         [0.4802],
#         [0.5083]], grad_fn=<SigmoidBackward>)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-7677986e85a6> in <module>()
#       2 num_epochs = 20
#       3 for e in range(num_epochs):
# ----> 4     losses, y = train_epoch(net, opt, criterion)
#       5     e_losses += losses
#       6 plt.plot(e_losses)
#
# ValueError: too many values to unpack (expected 2)

# %%
x_t = Variable(torch.randn(1, 50))
net.eval()
print(net(x_t))
x_1_t = Variable(torch.randn(1, 50) + 1.5)
print(net(x_1_t))
# Out:
# tensor([[0.0039]], grad_fn=<SigmoidBackward>)
# tensor([[1.0000]], grad_fn=<SigmoidBackward>)
