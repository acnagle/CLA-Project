# %% [markdown]
# ## Import Statements

# %%
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix, roc_curve, precision_recall_curve
from sklearn.naive_bayes import GaussianNB, MultinomialNB

import pandas as pd

from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Tahoma']
import matplotlib.pyplot as plt
# %matplotlib inline

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import seaborn as sns

pd.options.mode.chained_assignment = None
# np.random.seed(0)

# %% [markdown]
# ## Read in Data

# %%
data_path = '../Data/'

filenames = [
#     'CM2014_edit.csv',
    'CM2015_edit.csv',
    'CM2016_edit.csv',
    'CM2017_edit.csv',
    'CM2018_edit.csv',
    'mdcp.csv',
    'major_ion.csv',
    'Weather_Data.csv'
]

# cla_2014 = pd.read_csv(data_path + filenames[0], low_memory=False)
cla_2015_raw = pd.read_csv(data_path + filenames[0], low_memory=False)
cla_2016_raw = pd.read_csv(data_path + filenames[1], low_memory=False)
cla_2017_raw = pd.read_csv(data_path + filenames[2], low_memory=False)
cla_2018_raw = pd.read_csv(data_path + filenames[3], low_memory=False)
mdcp_raw = pd.read_csv(data_path + filenames[4], low_memory=False)    # Mendota buoy
weather_raw = pd.read_csv(data_path + filenames[6], error_bad_lines=False, low_memory=False)

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ### CLA Data

# %%
keep15 = [     # features to keep for years 2015-2017
    'correct_timestamp',
    'collectionSiteId',
    'lake',
    'algalBloom',
    'algalBloomSheen',
    'turbidity',
#     'waterTemp',
#     'waveIntensity',
    'lat',
    'long'
]

keep18 = [    # features to keep for 2018
    'sample_collection_time',
    'collectionSiteId',
    'lake',
    'algalBloom',
    'algalBloomSheen',
    'turbidity',
#     'waterTemp',
#     'waveIntensity',
    'latitiude',
    'longitude'
]

rename15 = {   # rename features for 2015-2017
    'collectionSiteId': 'site',
    'lat': 'latitude',
    'long': 'longitude',
    'correct_timestamp': 'date'
}

rename18 = {   # renamce features for 2018
    'collectionSiteId': 'site',
    'sample_collection_time': 'date',
    'latitiude': 'latitude'
}

cla_2015 = cla_2015_raw[keep15]
cla_2016 = cla_2016_raw[keep15]
cla_2017 = cla_2017_raw[keep15]
cla_2018 = cla_2018_raw[keep18]

cla_2015.rename(rename15, axis='columns', inplace=True)
cla_2016.rename(rename15, axis='columns', inplace=True)
cla_2017.rename(rename15, axis='columns', inplace=True)
cla_2018.rename(rename18, axis='columns', inplace=True)

# change data types
numeric = [    # list of numeric features
    'algalBloom',
    'algalBloomSheen',
    'turbidity',
#     'waterTemp',
#     'waveIntensity',
    'latitude',
    'longitude'
]

# convert data types
features = cla_2015.columns.values

for feat in features:
    if feat in numeric:
        cla_2015[feat] = pd.to_numeric(cla_2015[feat], errors='coerce')
        cla_2016[feat] = pd.to_numeric(cla_2016[feat], errors='coerce')
        cla_2017[feat] = pd.to_numeric(cla_2017[feat], errors='coerce')
        cla_2018[feat] = pd.to_numeric(cla_2018[feat], errors='coerce')
    
    if feat in ['site', 'lake']:
        cla_2015[feat] = cla_2015[feat].astype(str)
        cla_2016[feat] = cla_2016[feat].astype(str)
        cla_2017[feat] = cla_2017[feat].astype(str)
        cla_2018[feat] = cla_2018[feat].astype(str)
    
    if feat == 'date':
        cla_2015[feat] = pd.to_datetime(cla_2015[feat], errors='coerce')
        cla_2016[feat] = pd.to_datetime(cla_2016[feat], errors='coerce')
        cla_2017[feat] = pd.to_datetime(cla_2017[feat], errors='coerce')
        cla_2018[feat] = pd.to_datetime(cla_2018[feat], errors='coerce')
        
# remove nans
cla_2015.dropna(axis='rows', how='any', inplace=True)
cla_2016.dropna(axis='rows', how='any', inplace=True)
cla_2017.dropna(axis='rows', how='any', inplace=True)
cla_2018.dropna(axis='rows', how='any', inplace=True)

# remove any data point not on lake mendota
cla_2015 = cla_2015[cla_2015['lake'].str.contains('Mendota')]
cla_2016 = cla_2016[cla_2016['lake'].str.contains('Mendota')]
cla_2017 = cla_2017[cla_2017['lake'].str.contains('Mendota')]
cla_2018 = cla_2018[cla_2018['lake'].str.contains('Mendota')]

# set date as index
cla_2015.set_index('date', inplace=True)
cla_2016.set_index('date', inplace=True)
cla_2017.set_index('date', inplace=True)
cla_2018.set_index('date', inplace=True)

# sort data by dates
cla_2015.sort_values(by='date', inplace=True)
cla_2016.sort_values(by='date', inplace=True)
cla_2017.sort_values(by='date', inplace=True)
cla_2018.sort_values(by='date', inplace=True)

# resample, ffill and bfill
cla_2015 = cla_2015.resample('D').mean()
cla_2015.ffill(inplace=True)
cla_2015.bfill(inplace=True)

for date in cla_2015.index:
    if cla_2015.loc[date, 'algalBloomSheen'] > 0:
        cla_2015.loc[date, 'algalBloomSheen'] = 1

cla_2016 = cla_2016.resample('D').mean()
cla_2016.ffill(inplace=True)
cla_2016.bfill(inplace=True)

for date in cla_2016.index:
    if cla_2016.loc[date, 'algalBloomSheen'] > 0:
        cla_2016.loc[date, 'algalBloomSheen'] = 1

cla_2017 = cla_2017.resample('D').mean()
cla_2017.ffill(inplace=True)
cla_2017.bfill(inplace=True)

for date in cla_2017.index:
    if cla_2017.loc[date, 'algalBloomSheen'] > 0:
        cla_2017.loc[date, 'algalBloomSheen'] = 1

cla_2018 = cla_2018.resample('D').mean()
cla_2018.ffill(inplace=True)
cla_2018.bfill(inplace=True)

for date in cla_2018.index:
    if cla_2018.loc[date, 'algalBloomSheen'] > 0:
        cla_2018.loc[date, 'algalBloomSheen'] = 1
        
# only keep the dates of the official sampling season of each year
# cla_2015 = cla_2015[(cla_2015.index >= '2015-5-18') & (cla_2015.index <= '2015-9-4')]
# cla_2016 = cla_2016[(cla_2016.index >= '2016-5-25') & (cla_2016.index <= '2016-9-4')]
# cla_2017 = cla_2017[(cla_2017.index >= '2017-5-25') & (cla_2017.index <= '2017-9-4')]
# cla_2018 = cla_2018[(cla_2018.index >= '2018-5-25') & (cla_2018.index <= '2018-9-4')]

# %% [markdown]
# ### MDCP Data

# %%
keep_mdcp = [
    'sampledate',
    'sampletime',
    'air_temp',
    'rel_hum',
    'wind_speed',
    'wind_dir',
    'chlor',
    'phycocyanin',
    'do_raw',
    'do_sat',
    'do_wtemp',
    'pco2_ppm',
    'par',
    'par_below'
]

mdcp = mdcp_raw[keep_mdcp]
mdcp.ffill(inplace=True)
mdcp.bfill(inplace=True)

mdcp['date'] = mdcp['sampledate'] + ' ' + mdcp['sampletime']
mdcp['date'] = pd.to_datetime(mdcp['date'], errors='coerce')
mdcp.dropna(axis='rows', how='any', inplace=True)

mdcp = mdcp[[
    'date',
    'air_temp',
    'rel_hum',
    'wind_speed',
    'wind_dir',
    'chlor', 
    'phycocyanin',
    'do_raw',
    'do_sat',
    'do_wtemp',
    'pco2_ppm',
    'par',
    'par_below'
]]
mdcp.set_index('date', inplace=True)

mdcp = mdcp.resample('D').mean()
mdcp.ffill(inplace=True)
mdcp.bfill(inplace=True)

# %% [markdown]
# ### Weather Data

# %%
keep_weather = [
    'DATE',
    'REPORTTPYE',
    'DAILYMaximumDryBulbTemp',
    'DAILYMinimumDryBulbTemp',
    'DAILYAverageDryBulbTemp',
    'DAILYDeptFromNormalAverageTemp',
    'DAILYAverageDewPointTemp',
    'DAILYAverageWetBulbTemp',
    'DAILYPrecip',
    'DAILYAverageStationPressure',
    'DAILYAverageSeaLevelPressure'
]

weather = weather_raw[keep_weather]
# weather['REPORTTPYE'].dropna(axis='rows', how='any', inplace=True)
weather = weather.iloc[:-1]  # remove last entry since it has NaN in REPORTTPYE

weather = weather[weather['REPORTTPYE'].str.contains('SOD')]    # only keep summary of day (SOD) info
weather = weather.drop(['REPORTTPYE'], axis='columns')
weather['DATE'] = pd.to_datetime(weather['DATE'], errors='coerce')

weather.set_index('DATE', inplace=True)
weather = weather.resample('D').ffill()    # ffill because SOD is a mean already. SOD may not exist for a date
weather.ffill(inplace=True)
weather.bfill(inplace=True)

# %% [markdown]
# ## Join CLA, MDCP, and Weather Data

# %%
# Append CLA data
cla = cla_2015.append(cla_2016)
cla = cla.append(cla_2017)
cla = cla.append(cla_2018)

# Insert MDCP data
data = cla.join(mdcp, how='inner')

# Insert weather data
data = data.join(weather, how='inner')

# sine/cosine transformation of month of year and wind direction
data['cos_month'] = np.cos(2 * np.pi * (data.index.month.values / 12))
data['sin_month'] = np.sin(2 * np.pi * (data.index.month.values / 12))

data['cos_wind_dir'] = np.cos(2 * np.pi * (data['wind_dir'] / 12))
data['sin_wind_dir'] = np.sin(2 * np.pi * (data['wind_dir'] / 12))
data = data.drop(['wind_dir'], axis='columns')

# Replace 'T' and 's' in 'DAILYPrecip' column
for date in data.index:
    if 'T' in data.loc[date, 'DAILYPrecip']:
        data.loc[date, 'DAILYPrecip'] = 0.01
    elif 's' in data.loc[date, 'DAILYPrecip']:
        data.loc[date, 'DAILYPrecip'] = 0

# Make every feature numeric
for col in data.columns.values:
    if type(data[col].values[0]) != np.float64:
        data[col] = pd.to_numeric(data[col], errors='coerce')
        
# create indicator features for whether there was rain or a bloom one day ago, or within three days or a week ago
precip = (data['DAILYPrecip'] > 0).astype(int)   # convert precipitation to boolean values
# data['DAILYPrecip_one_day'] = precip.shift(1)
# data['DAILYPrecip_three_day'] = precip.rolling(window=3, min_periods=1).sum()    # NOTE THAT THIS IS DEPENDENT ON CURRENT VALUE
# data['DAILYPrecip_one_week'] = precip.rolling(window=7, min_periods=1).sum()

# data['algalBloomSheen_one_day'] = data['algalBloomSheen'].shift(1)
# data['algalBloomSheen_three_day'] = data[['algalBloomSheen']].shift(1).rolling(3).sum()
# data['algalBloomSheen_one_week'] = data[['algalBloomSheen']].shift(1).rolling(7).sum()

# shift algalbloomsheen by -1 to predict next day algal bloom
data['DAILYPrecip_one_day'] = precip
data['DAILYPrecip_three_day'] = precip.rolling(window=3, min_periods=1).sum()    # NOTE THAT THIS IS DEPENDENT ON CURRENT VALUE
data['DAILYPrecip_one_week'] = precip.rolling(window=7, min_periods=1).sum()
data['algalBloomSheen_one_day'] = data['algalBloomSheen']
data['algalBloomSheen_three_day'] = data[['algalBloomSheen']].rolling(3, min_periods=1).sum()
data['algalBloomSheen_one_week'] = data[['algalBloomSheen']].rolling(7, min_periods=1).sum()
data['algalBloomSheen'] = data['algalBloomSheen'].shift(-1)

data.dropna(axis='rows', how='any', inplace=True)

labels = data[['algalBloomSheen']]
data = data.drop(['latitude', 'longitude', 'algalBloom', 'algalBloomSheen'], axis='columns')

# %%
data[['DAILYPrecip',
      'DAILYPrecip_one_day',
      'DAILYPrecip_three_day',
      'DAILYPrecip_one_week',
      'algalBloomSheen_one_day',
      'algalBloomSheen_three_day',
      'algalBloomSheen_one_week'
     ]].head()
# Out:
#             DAILYPrecip  DAILYPrecip_one_day  DAILYPrecip_three_day  \
# 2015-05-16         0.03                  1.0                    2.0
# 2015-05-17         0.01                  1.0                    3.0
# 2015-05-18         1.57                  1.0                    3.0
# 2015-05-19         0.00                  1.0                    2.0
# 2015-05-20         0.01                  0.0                    2.0
#
#             DAILYPrecip_one_week  algalBloomSheen_one_day  \
# 2015-05-16                   2.0                      0.0
# 2015-05-17                   3.0                      0.0
# 2015-05-18                   4.0                      0.0
# 2015-05-19                   4.0                      0.0
# 2015-05-20                   5.0                      1.0
#
#             algalBloomSheen_three_day  algalBloomSheen_one_week
# 2015-05-16                        0.0                       0.0
# 2015-05-17                        0.0                       0.0
# 2015-05-18                        0.0                       0.0
# 2015-05-19                        0.0                       0.0
# 2015-05-20                        1.0                       1.0

# %% [markdown]
# ## Define Models

# %%
logic = LogisticRegression(    # gives more false positives, but not so many false negatives!!!!!
    penalty='l1',              # this model might be better without weather data actually
    tol=0.0001,
    C=1,
    fit_intercept=True,
    class_weight='balanced',
    solver='liblinear'
)

svc = SVC(                     # gives even slightly fewer false negatives than logic
    C=1,
    kernel='poly',
    degree=6,
    gamma='auto',
    coef0=1,
    probability=True,
    tol=0.001,
    class_weight='balanced',
    max_iter=10000
)

rfc = RandomForestClassifier(       # BEST MODEL
    n_estimators=100,
    max_depth=6,
    criterion='gini',
    bootstrap=True,
    class_weight='balanced'
)

mlp = MLPClassifier(
    hidden_layer_sizes=(20, 50, 50, 20),
    activation='relu',
    solver='adam',
    alpha=0.0001,
    batch_size=8,
    learning_rate='adaptive',
    learning_rate_init=0.001,
    power_t=0.5,
    max_iter=200,
    shuffle=True,
    tol=0.0001,
    momentum=0.9,
    nesterovs_momentum=True,
    early_stopping=False,
    validation_fraction=0.1,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-8,
    n_iter_no_change=10
)

model = rfc

########################################
########################################
########################################
# TODO TRY PARAMETER TUNING THE SVC, WILL POLY SVC WORK??                       -- DONE!!
# TODO TRY CHANGING ROLLING AND SHIFTED BOOLEAN PRECIP DATA TO ACTUAL AMOUNTS   -- DONE!!
# TODO TRY LOG TRANSFORMS AND MOVING AVERAGE AND STD ON SOME FEATURES
# TODO CROSS VALIDATED TRAINING CURVE                                           -- NOT APPLICABLE!!
# TODO TRY TRAINING ON ALL DATA BEFORE 2018, AND TEST ON DATA AFTER             -- DONE!!
# TODO TRY USING DATA ONLY FROM SAMPLING SEASON                                 -- DONE!!
# TODO TRY USING 2014 DATA                                                      -- DONE!!
# TODO ALSO TRY PARAMETER TUNING ON LOGISTIC REGRESSION                         -- DONE!! 
# TODO TRY ONLY OPTIMIZING F1 SCORE WHEN PARAMETER TUNING                       -- DONE!!
# TODO TRY FORECASTING MODEL                                                    -- DONE!!
# TODO CHECK CORRELATION AMONG VARIABLES                                        -- DONE!!
# TODO TRY REMOVING REDUNDANT FEATURES. THE PROBLEM IS THAT PREDICTIONS ARE
#    MADE ON AVERAGE DAILIES, WHICH IS SORT OF LIKE USING FUTURE DATA. TRY
#    ONLY USING BINARY OR DISCRETE FEATURES FOR DAILY AVERAGES, ETC DID IT
#    RAIN OR NOT?
# TODO HYPERPARAMETER TUNE MODELS FOR PREDICTING NEXT DAY 
########################################
########################################
########################################

# %% [markdown]
# ## Run Model (Predict on 2018)

# %% [markdown]
# ### Parameter Tune Models on Data Before 2018

# %%
train_val_years = [2015, 2016, 2017]

rfc_params = {
    'n_estimators': [10, 20, 50, 100, 200, 500, 1000],
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10, 11]
}

# best_f1_roc = 0     # The harmonic mean of F1 and ROC AUC Scores is best
best_avg_f1 = 0
best_params = {}

for est in rfc_params['n_estimators']:
    for cri in rfc_params['criterion']:
        for dep in rfc_params['max_depth']:
            model = RandomForestClassifier(
                n_estimators=est,
                criterion=cri,
                max_depth=dep,
                bootstrap=True,
                class_weight='balanced'
            )
            
            train_acc = []
            train_f1 = []
            train_roc = []
            
            val_acc = []
            val_f1 = []
            val_roc = []
            
            f1_roc = []
            
            conf_matrix = np.zeros(shape=(2, 2))
            
            for i in range(len(train_val_years)-1):
                X_train = data[data.index.year <= train_val_years[i]].values
                X_val = data[data.index.year == train_val_years[i+1]].values

                y_train = labels[labels.index.year <= train_val_years[i]].values
                y_val = labels[labels.index.year == train_val_years[i+1]].values

                y_train = np.reshape(y_train.astype(int), newshape=(X_train.shape[0]))
                y_val = np.reshape(y_val.astype(int), newshape=(X_val.shape[0]))
                
                model.fit(X_train, y_train)
                y_pred = model.predict(X_val)
                y_prob = model.predict_proba(X_val)[:, 1]

                train_acc.append(model.score(X_train, y_train))
                train_f1.append(f1_score(y_train, model.predict(X_train), average='weighted'))
                train_roc.append(roc_auc_score(y_train, model.predict_proba(X_train)[:, 1], average='weighted'))

                val_acc.append(model.score(X_val, y_val))
                val_f1.append(f1_score(y_val, y_pred, average='weighted'))
                val_roc.append(roc_auc_score(y_val, y_prob, average='weighted'))

                conf_matrix += confusion_matrix(y_val, y_pred)

#                 f1_roc.append((2 * val_roc[i] * val_f1[i]) / (val_roc[i] + val_f1[i]))
                f1_roc.append(np.sqrt(val_roc[i] * val_f1[i]))

                
            avg_train_acc = sum(train_acc) / (len(train_val_years)-1)
            avg_train_f1 = sum(train_f1) / (len(train_val_years)-1)
            avg_train_roc = sum(train_roc) / (len(train_val_years)-1)
            
            avg_val_acc = sum(val_acc) / (len(train_val_years)-1)
            avg_val_f1 = sum(val_f1) / (len(train_val_years)-1)
            avg_val_roc = sum(val_roc) / (len(train_val_years)-1)
            
            conf_matrix /= (len(train_val_years)-1)
            
#             avg_f1_roc = sum(f1_roc) / (len(train_val_years)-1)
            
            if avg_val_f1 > best_avg_f1:
                best_avg_f1 = avg_val_f1
                best_params['n_estimators'] = est
                best_params['criterion'] = cri
                best_params['max_depth'] = dep
                best_conf_matrix = conf_matrix
#                 best_avg_f1 = avg_val_f1
                best_avg_roc = avg_val_roc
                
            print('Results for n_estimators=' + str(est) + ', criterion=' + str(cri) + ', max_depth=' + str(dep))
            print('Average Train Accuracy: %0.4f' % avg_train_acc)
            print('Average Train F1 Score: %0.4f' % avg_train_f1)
            print('Average Train ROC AUC: %0.4f\n' % avg_train_roc)

            print('Average Validation Accuracy: %0.4f' % avg_val_acc)
            print('Average Validation F1 Score: %0.4f' % avg_val_f1)
            print('Average Validation ROC AUC: %0.4f' % avg_val_roc)
            print()
    #         print('Average Harmonic Mean of F1 Score and ROC AUC Score: %0.4f' % avg_f1_roc)

            print('\nAverage Confusion Matrix:\n')
            print(pd.DataFrame(conf_matrix))
            print('\n\n\n')
            
# print('Best Average F1-ROC AUC Score: %0.4f' % best_f1_roc)
print('Best Average F1: %0.4f ' % best_avg_f1)
print('Best Average ROC: %0.4f ' % best_avg_roc)
print('Best Model Parameters:')
print(best_params)
print('Best Confusion Matrix:')
print(best_conf_matrix)
print('\n\n\n')
# Out:
# Results for n_estimators=10, criterion=gini, max_depth=3
# Average Train Accuracy: 0.8591
# Average Train F1 Score: 0.8632
# Average Train ROC AUC: 0.9522
#
# Average Validation Accuracy: 0.7814
# Average Validation F1 Score: 0.7868
# Average Validation ROC AUC: 0.7679
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  108.5  22.0
# 1   16.0  26.5
#
#
#
#
# Results for n_estimators=10, criterion=gini, max_depth=4
# Average Train Accuracy: 0.9024
# Average Train F1 Score: 0.9040
# Average Train ROC AUC: 0.9674
#
# Average Validation Accuracy: 0.7274
# Average Validation F1 Score: 0.7237
# Average Validation ROC AUC: 0.7073
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  109.5  21.0
# 1   26.0  16.5
#
#
#
#
# Results for n_estimators=10, criterion=gini, max_depth=5
# Average Train Accuracy: 0.9198
# Average Train F1 Score: 0.9219
# Average Train ROC AUC: 0.9803
#
# Average Validation Accuracy: 0.7483
# Average Validation F1 Score: 0.7516
# Average Validation ROC AUC: 0.7542
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  107.0  23.5
# 1   20.5  22.0
#
#
#
#
# Results for n_estimators=10, criterion=gini, max_depth=6
# Average Train Accuracy: 0.9452
# Average Train F1 Score: 0.9465
# Average Train ROC AUC: 0.9894
#
# Average Validation Accuracy: 0.6628
# Average Validation F1 Score: 0.6432
# Average Validation ROC AUC: 0.6572
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  106.0  24.5
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=10, criterion=gini, max_depth=7
# Average Train Accuracy: 0.9830
# Average Train F1 Score: 0.9831
# Average Train ROC AUC: 0.9983
#
# Average Validation Accuracy: 0.7137
# Average Validation F1 Score: 0.6837
# Average Validation ROC AUC: 0.6609
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   34.5   8.0
#
#
#
#
# Results for n_estimators=10, criterion=gini, max_depth=8
# Average Train Accuracy: 0.9664
# Average Train F1 Score: 0.9666
# Average Train ROC AUC: 0.9968
#
# Average Validation Accuracy: 0.7182
# Average Validation F1 Score: 0.6910
# Average Validation ROC AUC: 0.6918
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.0  15.5
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=10, criterion=gini, max_depth=9
# Average Train Accuracy: 0.9776
# Average Train F1 Score: 0.9777
# Average Train ROC AUC: 0.9977
#
# Average Validation Accuracy: 0.7203
# Average Validation F1 Score: 0.6720
# Average Validation ROC AUC: 0.6484
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   37.0   5.5
#
#
#
#
# Results for n_estimators=10, criterion=gini, max_depth=10
# Average Train Accuracy: 0.9758
# Average Train F1 Score: 0.9758
# Average Train ROC AUC: 0.9980
#
# Average Validation Accuracy: 0.6790
# Average Validation F1 Score: 0.6829
# Average Validation ROC AUC: 0.7024
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  102.5  28.0
# 1   26.5  16.0
#
#
#
#
# Results for n_estimators=10, criterion=gini, max_depth=11
# Average Train Accuracy: 0.9906
# Average Train F1 Score: 0.9906
# Average Train ROC AUC: 0.9998
#
# Average Validation Accuracy: 0.7203
# Average Validation F1 Score: 0.7040
# Average Validation ROC AUC: 0.7065
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  111.5  19.0
# 1   29.5  13.0
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=3
# Average Train Accuracy: 0.8681
# Average Train F1 Score: 0.8720
# Average Train ROC AUC: 0.9461
#
# Average Validation Accuracy: 0.7246
# Average Validation F1 Score: 0.7405
# Average Validation ROC AUC: 0.7536
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  98.5  32.0
# 1  15.0  27.5
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=4
# Average Train Accuracy: 0.9011
# Average Train F1 Score: 0.9030
# Average Train ROC AUC: 0.9677
#
# Average Validation Accuracy: 0.6717
# Average Validation F1 Score: 0.6920
# Average Validation ROC AUC: 0.7065
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  94.0  36.5
# 1  18.5  24.0
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=5
# Average Train Accuracy: 0.9378
# Average Train F1 Score: 0.9390
# Average Train ROC AUC: 0.9856
#
# Average Validation Accuracy: 0.6751
# Average Validation F1 Score: 0.6836
# Average Validation ROC AUC: 0.7212
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  99.5  31.0
# 1  24.0  18.5
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=6
# Average Train Accuracy: 0.9578
# Average Train F1 Score: 0.9583
# Average Train ROC AUC: 0.9927
#
# Average Validation Accuracy: 0.7523
# Average Validation F1 Score: 0.7259
# Average Validation ROC AUC: 0.7202
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   30.5  12.0
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=7
# Average Train Accuracy: 0.9578
# Average Train F1 Score: 0.9588
# Average Train ROC AUC: 0.9967
#
# Average Validation Accuracy: 0.7490
# Average Validation F1 Score: 0.7314
# Average Validation ROC AUC: 0.7114
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   29.0  13.5
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=8
# Average Train Accuracy: 0.9762
# Average Train F1 Score: 0.9763
# Average Train ROC AUC: 0.9967
#
# Average Validation Accuracy: 0.7346
# Average Validation F1 Score: 0.7045
# Average Validation ROC AUC: 0.6738
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=9
# Average Train Accuracy: 0.9714
# Average Train F1 Score: 0.9712
# Average Train ROC AUC: 0.9980
#
# Average Validation Accuracy: 0.7769
# Average Validation F1 Score: 0.7586
# Average Validation ROC AUC: 0.7414
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   27.5  15.0
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=10
# Average Train Accuracy: 0.9812
# Average Train F1 Score: 0.9811
# Average Train ROC AUC: 0.9995
#
# Average Validation Accuracy: 0.7535
# Average Validation F1 Score: 0.7222
# Average Validation ROC AUC: 0.7026
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.0  13.5
# 1   29.5  13.0
#
#
#
#
# Results for n_estimators=10, criterion=entropy, max_depth=11
# Average Train Accuracy: 0.9928
# Average Train F1 Score: 0.9927
# Average Train ROC AUC: 0.9997
#
# Average Validation Accuracy: 0.7288
# Average Validation F1 Score: 0.6900
# Average Validation ROC AUC: 0.7240
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.0  12.5
# 1   35.0   7.5
#
#
#
#
# Results for n_estimators=20, criterion=gini, max_depth=3
# Average Train Accuracy: 0.8809
# Average Train F1 Score: 0.8845
# Average Train ROC AUC: 0.9522
#
# Average Validation Accuracy: 0.7546
# Average Validation F1 Score: 0.7639
# Average Validation ROC AUC: 0.7412
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  105.0  25.5
# 1   16.5  26.0
#
#
#
#
# Results for n_estimators=20, criterion=gini, max_depth=4
# Average Train Accuracy: 0.8859
# Average Train F1 Score: 0.8893
# Average Train ROC AUC: 0.9715
#
# Average Validation Accuracy: 0.6692
# Average Validation F1 Score: 0.6775
# Average Validation ROC AUC: 0.7348
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  96.5  34.0
# 1  22.0  20.5
#
#
#
#
# Results for n_estimators=20, criterion=gini, max_depth=5
# Average Train Accuracy: 0.9306
# Average Train F1 Score: 0.9316
# Average Train ROC AUC: 0.9830
#
# Average Validation Accuracy: 0.6869
# Average Validation F1 Score: 0.6737
# Average Validation ROC AUC: 0.7002
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  107.5  23.0
# 1   30.5  12.0
#
#
#
#
# Results for n_estimators=20, criterion=gini, max_depth=6
# Average Train Accuracy: 0.9632
# Average Train F1 Score: 0.9639
# Average Train ROC AUC: 0.9953
#
# Average Validation Accuracy: 0.7084
# Average Validation F1 Score: 0.6794
# Average Validation ROC AUC: 0.6975
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  112.5  18.0
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=20, criterion=gini, max_depth=7
# Average Train Accuracy: 0.9834
# Average Train F1 Score: 0.9835
# Average Train ROC AUC: 0.9978
#
# Average Validation Accuracy: 0.7084
# Average Validation F1 Score: 0.6896
# Average Validation ROC AUC: 0.7227
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  111.5  19.0
# 1   31.0  11.5
#
#
#
#
# Results for n_estimators=20, criterion=gini, max_depth=8
# Average Train Accuracy: 0.9852
# Average Train F1 Score: 0.9853
# Average Train ROC AUC: 0.9988
#
# Average Validation Accuracy: 0.7118
# Average Validation F1 Score: 0.6852
# Average Validation ROC AUC: 0.7186
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  112.0  18.5
# 1   31.5  11.0
#
#
#
#
# Results for n_estimators=20, criterion=gini, max_depth=9
# Average Train Accuracy: 0.9910
# Average Train F1 Score: 0.9911
# Average Train ROC AUC: 0.9995
#
# Average Validation Accuracy: 0.7163
# Average Validation F1 Score: 0.6713
# Average Validation ROC AUC: 0.7020
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   34.0   8.5
# Results for n_estimators=20, criterion=gini, max_depth=10
# Average Train Accuracy: 0.9910
# Average Train F1 Score: 0.9911
# Average Train ROC AUC: 0.9995
#
# Average Validation Accuracy: 0.7476
# Average Validation F1 Score: 0.7063
# Average Validation ROC AUC: 0.7204
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=20, criterion=gini, max_depth=11
# Average Train Accuracy: 0.9928
# Average Train F1 Score: 0.9928
# Average Train ROC AUC: 0.9998
#
# Average Validation Accuracy: 0.6947
# Average Validation F1 Score: 0.6647
# Average Validation ROC AUC: 0.6889
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  110.5  20.0
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=3
# Average Train Accuracy: 0.8533
# Average Train F1 Score: 0.8578
# Average Train ROC AUC: 0.9513
#
# Average Validation Accuracy: 0.7658
# Average Validation F1 Score: 0.7735
# Average Validation ROC AUC: 0.7625
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  106.0  24.5
# 1   16.0  26.5
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=4
# Average Train Accuracy: 0.8859
# Average Train F1 Score: 0.8892
# Average Train ROC AUC: 0.9719
#
# Average Validation Accuracy: 0.7644
# Average Validation F1 Score: 0.7727
# Average Validation ROC AUC: 0.7508
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  106.0  24.5
# 1   16.0  26.5
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=5
# Average Train Accuracy: 0.9220
# Average Train F1 Score: 0.9243
# Average Train ROC AUC: 0.9870
#
# Average Validation Accuracy: 0.7607
# Average Validation F1 Score: 0.7405
# Average Validation ROC AUC: 0.7385
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.0  13.5
# 1   28.5  14.0
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=6
# Average Train Accuracy: 0.9596
# Average Train F1 Score: 0.9604
# Average Train ROC AUC: 0.9950
#
# Average Validation Accuracy: 0.7627
# Average Validation F1 Score: 0.7565
# Average Validation ROC AUC: 0.7587
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  112.5  18.0
# 1   24.0  18.5
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=7
# Average Train Accuracy: 0.9766
# Average Train F1 Score: 0.9771
# Average Train ROC AUC: 0.9973
#
# Average Validation Accuracy: 0.7502
# Average Validation F1 Score: 0.7307
# Average Validation ROC AUC: 0.7261
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   28.5  14.0
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=8
# Average Train Accuracy: 0.9892
# Average Train F1 Score: 0.9892
# Average Train ROC AUC: 0.9989
#
# Average Validation Accuracy: 0.7320
# Average Validation F1 Score: 0.7095
# Average Validation ROC AUC: 0.7328
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.5  16.0
# 1   30.5  12.0
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=9
# Average Train Accuracy: 0.9946
# Average Train F1 Score: 0.9946
# Average Train ROC AUC: 0.9999
#
# Average Validation Accuracy: 0.7111
# Average Validation F1 Score: 0.6849
# Average Validation ROC AUC: 0.6924
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  111.5  19.0
# 1   31.0  11.5
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=10
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.6974
# Average Validation F1 Score: 0.6661
# Average Validation ROC AUC: 0.6949
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  110.5  20.0
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=20, criterion=entropy, max_depth=11
# Average Train Accuracy: 0.9942
# Average Train F1 Score: 0.9942
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7307
# Average Validation F1 Score: 0.6899
# Average Validation ROC AUC: 0.7143
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   34.0   8.5
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=3
# Average Train Accuracy: 0.8671
# Average Train F1 Score: 0.8707
# Average Train ROC AUC: 0.9573
#
# Average Validation Accuracy: 0.7037
# Average Validation F1 Score: 0.7224
# Average Validation ROC AUC: 0.7420
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  96.0  34.5
# 1  15.5  27.0
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=4
# Average Train Accuracy: 0.8935
# Average Train F1 Score: 0.8964
# Average Train ROC AUC: 0.9747
#
# Average Validation Accuracy: 0.6992
# Average Validation F1 Score: 0.7082
# Average Validation ROC AUC: 0.7282
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  101.5  29.0
# 1   22.0  20.5
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=5
# Average Train Accuracy: 0.9440
# Average Train F1 Score: 0.9450
# Average Train ROC AUC: 0.9883
#
# Average Validation Accuracy: 0.6922
# Average Validation F1 Score: 0.6689
# Average Validation ROC AUC: 0.7084
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  110.5  20.0
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=6
# Average Train Accuracy: 0.9592
# Average Train F1 Score: 0.9598
# Average Train ROC AUC: 0.9947
#
# Average Validation Accuracy: 0.7561
# Average Validation F1 Score: 0.7382
# Average Validation ROC AUC: 0.7456
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.5  14.0
# 1   28.5  14.0
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=7
# Average Train Accuracy: 0.9798
# Average Train F1 Score: 0.9800
# Average Train ROC AUC: 0.9967
#
# Average Validation Accuracy: 0.7340
# Average Validation F1 Score: 0.6859
# Average Validation ROC AUC: 0.7294
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   35.5   7.0
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=8
# Average Train Accuracy: 0.9892
# Average Train F1 Score: 0.9893
# Average Train ROC AUC: 0.9984
#
# Average Validation Accuracy: 0.7158
# Average Validation F1 Score: 0.6690
# Average Validation ROC AUC: 0.7192
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.0  13.5
# 1   36.0   6.5
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=9
# Average Train Accuracy: 0.9946
# Average Train F1 Score: 0.9946
# Average Train ROC AUC: 0.9994
#
# Average Validation Accuracy: 0.7105
# Average Validation F1 Score: 0.6715
# Average Validation ROC AUC: 0.6937
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.0  16.5
# 1   33.5   9.0
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=10
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7405
# Average Validation F1 Score: 0.6925
# Average Validation ROC AUC: 0.7139
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   35.0   7.5
#
#
#
#
# Results for n_estimators=50, criterion=gini, max_depth=11
# Average Train Accuracy: 0.9942
# Average Train F1 Score: 0.9942
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7640
# Average Validation F1 Score: 0.7086
# Average Validation ROC AUC: 0.7189
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  124.0  6.5
# 1   35.0  7.5
#
#
#
#
# Results for n_estimators=50, criterion=entropy, max_depth=3
# Average Train Accuracy: 0.8649
# Average Train F1 Score: 0.8691
# Average Train ROC AUC: 0.9575
#
# Average Validation Accuracy: 0.7768
# Average Validation F1 Score: 0.7844
# Average Validation ROC AUC: 0.7650
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  107.0  23.5
# 1   15.0  27.5
#
#
#
#
# Results for n_estimators=50, criterion=entropy, max_depth=4
# Average Train Accuracy: 0.9051
# Average Train F1 Score: 0.9076
# Average Train ROC AUC: 0.9756
#
# Average Validation Accuracy: 0.7221
# Average Validation F1 Score: 0.7286
# Average Validation ROC AUC: 0.7499
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  104.5  26.0
# 1   21.5  21.0
#
#
#
#
# Results for n_estimators=50, criterion=entropy, max_depth=5
# Average Train Accuracy: 0.9318
# Average Train F1 Score: 0.9334
# Average Train ROC AUC: 0.9880
#
# Average Validation Accuracy: 0.7470
# Average Validation F1 Score: 0.7462
# Average Validation ROC AUC: 0.7414
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  109.5  21.0
# 1   23.0  19.5
#
#
#
#
# Results for n_estimators=50, criterion=entropy, max_depth=6
# Average Train Accuracy: 0.9690
# Average Train F1 Score: 0.9696
# Average Train ROC AUC: 0.9944
#
# Average Validation Accuracy: 0.7307
# Average Validation F1 Score: 0.7103
# Average Validation ROC AUC: 0.7487
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  113.5  17.0
# 1   30.0  12.5
#
#
#
#
# Results for n_estimators=50, criterion=entropy, max_depth=7
# Average Train Accuracy: 0.9784
# Average Train F1 Score: 0.9787
# Average Train ROC AUC: 0.9976
#
# Average Validation Accuracy: 0.7274
# Average Validation F1 Score: 0.7144
# Average Validation ROC AUC: 0.7529
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  111.5  19.0
# 1   28.0  14.5
#
#
#
#
# Results for n_estimators=50, criterion=entropy, max_depth=8
# Average Train Accuracy: 0.9924
# Average Train F1 Score: 0.9924
# Average Train ROC AUC: 0.9998
#
# Average Validation Accuracy: 0.7158
# Average Validation F1 Score: 0.6847
# Average Validation ROC AUC: 0.7170
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  113.5  17.0
# 1   32.5  10.0
# Results for n_estimators=50, criterion=entropy, max_depth=9
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7268
# Average Validation F1 Score: 0.6724
# Average Validation ROC AUC: 0.7099
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   36.0   6.5
#
#
#
#
# Results for n_estimators=50, criterion=entropy, max_depth=10
# Average Train Accuracy: 0.9982
# Average Train F1 Score: 0.9982
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7163
# Average Validation F1 Score: 0.6979
# Average Validation ROC AUC: 0.7312
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  110.5  20.0
# 1   29.0  13.5
#
#
#
#
# Results for n_estimators=50, criterion=entropy, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7576
# Average Validation F1 Score: 0.7089
# Average Validation ROC AUC: 0.7608
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.5  10.0
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=3
# Average Train Accuracy: 0.8631
# Average Train F1 Score: 0.8673
# Average Train ROC AUC: 0.9592
#
# Average Validation Accuracy: 0.7853
# Average Validation F1 Score: 0.7913
# Average Validation ROC AUC: 0.7563
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  108.5  22.0
# 1   15.0  27.5
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=4
# Average Train Accuracy: 0.9015
# Average Train F1 Score: 0.9042
# Average Train ROC AUC: 0.9798
#
# Average Validation Accuracy: 0.7000
# Average Validation F1 Score: 0.6981
# Average Validation ROC AUC: 0.7440
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  104.5  26.0
# 1   25.5  17.0
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=5
# Average Train Accuracy: 0.9314
# Average Train F1 Score: 0.9331
# Average Train ROC AUC: 0.9870
#
# Average Validation Accuracy: 0.7463
# Average Validation F1 Score: 0.7326
# Average Validation ROC AUC: 0.7454
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  113.5  17.0
# 1   27.0  15.5
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=6
# Average Train Accuracy: 0.9628
# Average Train F1 Score: 0.9634
# Average Train ROC AUC: 0.9955
#
# Average Validation Accuracy: 0.7099
# Average Validation F1 Score: 0.6822
# Average Validation ROC AUC: 0.7368
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  111.5  19.0
# 1   31.5  11.0
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=7
# Average Train Accuracy: 0.9852
# Average Train F1 Score: 0.9853
# Average Train ROC AUC: 0.9981
#
# Average Validation Accuracy: 0.7216
# Average Validation F1 Score: 0.6899
# Average Validation ROC AUC: 0.7274
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.0  16.5
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=8
# Average Train Accuracy: 0.9928
# Average Train F1 Score: 0.9929
# Average Train ROC AUC: 0.9991
#
# Average Validation Accuracy: 0.7327
# Average Validation F1 Score: 0.6973
# Average Validation ROC AUC: 0.7468
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=9
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7170
# Average Validation F1 Score: 0.6725
# Average Validation ROC AUC: 0.7314
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   34.0   8.5
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=10
# Average Train Accuracy: 0.9982
# Average Train F1 Score: 0.9982
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7183
# Average Validation F1 Score: 0.6717
# Average Validation ROC AUC: 0.7134
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.0  13.5
# 1   35.5   7.0
#
#
#
#
# Results for n_estimators=100, criterion=gini, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7197
# Average Validation F1 Score: 0.6750
# Average Validation ROC AUC: 0.7256
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   36.0   6.5
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=3
# Average Train Accuracy: 0.8693
# Average Train F1 Score: 0.8734
# Average Train ROC AUC: 0.9584
#
# Average Validation Accuracy: 0.7539
# Average Validation F1 Score: 0.7663
# Average Validation ROC AUC: 0.7581
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  103.0  27.5
# 1   14.5  28.0
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=4
# Average Train Accuracy: 0.8957
# Average Train F1 Score: 0.8988
# Average Train ROC AUC: 0.9761
#
# Average Validation Accuracy: 0.7639
# Average Validation F1 Score: 0.7671
# Average Validation ROC AUC: 0.7642
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  109.0  21.5
# 1   19.5  23.0
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=5
# Average Train Accuracy: 0.9278
# Average Train F1 Score: 0.9294
# Average Train ROC AUC: 0.9879
#
# Average Validation Accuracy: 0.7449
# Average Validation F1 Score: 0.7463
# Average Validation ROC AUC: 0.7474
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  108.5  22.0
# 1   22.0  20.5
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=6
# Average Train Accuracy: 0.9588
# Average Train F1 Score: 0.9596
# Average Train ROC AUC: 0.9953
#
# Average Validation Accuracy: 0.7196
# Average Validation F1 Score: 0.6971
# Average Validation ROC AUC: 0.7559
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  112.0  18.5
# 1   30.0  12.5
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=7
# Average Train Accuracy: 0.9852
# Average Train F1 Score: 0.9853
# Average Train ROC AUC: 0.9994
#
# Average Validation Accuracy: 0.7503
# Average Validation F1 Score: 0.7127
# Average Validation ROC AUC: 0.7443
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=8
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7431
# Average Validation F1 Score: 0.7147
# Average Validation ROC AUC: 0.7578
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.5  14.0
# 1   31.0  11.5
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=9
# Average Train Accuracy: 0.9982
# Average Train F1 Score: 0.9982
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7569
# Average Validation F1 Score: 0.7222
# Average Validation ROC AUC: 0.7431
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   32.5  10.0
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=10
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7555
# Average Validation F1 Score: 0.7142
# Average Validation ROC AUC: 0.7442
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  121.0  9.5
# 1   33.5  9.0
#
#
#
#
# Results for n_estimators=100, criterion=entropy, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7347
# Average Validation F1 Score: 0.6885
# Average Validation ROC AUC: 0.7385
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   35.0   7.5
#
#
#
#
# Results for n_estimators=200, criterion=gini, max_depth=3
# Average Train Accuracy: 0.8685
# Average Train F1 Score: 0.8724
# Average Train ROC AUC: 0.9598
#
# Average Validation Accuracy: 0.7441
# Average Validation F1 Score: 0.7579
# Average Validation ROC AUC: 0.7537
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  101.5  29.0
# 1   14.5  28.0
#
#
#
#
# Results for n_estimators=200, criterion=gini, max_depth=4
# Average Train Accuracy: 0.9019
# Average Train F1 Score: 0.9047
# Average Train ROC AUC: 0.9771
#
# Average Validation Accuracy: 0.7541
# Average Validation F1 Score: 0.7553
# Average Validation ROC AUC: 0.7519
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  109.5  21.0
# 1   21.5  21.0
#
#
#
#
# Results for n_estimators=200, criterion=gini, max_depth=5
# Average Train Accuracy: 0.9282
# Average Train F1 Score: 0.9300
# Average Train ROC AUC: 0.9887
#
# Average Validation Accuracy: 0.7209
# Average Validation F1 Score: 0.7108
# Average Validation ROC AUC: 0.7405
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  109.5  21.0
# 1   27.5  15.0
#
#
#
#
# Results for n_estimators=200, criterion=gini, max_depth=6
# Average Train Accuracy: 0.9664
# Average Train F1 Score: 0.9670
# Average Train ROC AUC: 0.9970
#
# Average Validation Accuracy: 0.7471
# Average Validation F1 Score: 0.7171
# Average Validation ROC AUC: 0.7395
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   31.5  11.0
# Results for n_estimators=200, criterion=gini, max_depth=7
# Average Train Accuracy: 0.9892
# Average Train F1 Score: 0.9893
# Average Train ROC AUC: 0.9982
#
# Average Validation Accuracy: 0.7354
# Average Validation F1 Score: 0.6896
# Average Validation ROC AUC: 0.7251
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   35.0   7.5
#
#
#
#
# Results for n_estimators=200, criterion=gini, max_depth=8
# Average Train Accuracy: 0.9946
# Average Train F1 Score: 0.9946
# Average Train ROC AUC: 0.9995
#
# Average Validation Accuracy: 0.7425
# Average Validation F1 Score: 0.6885
# Average Validation ROC AUC: 0.7353
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  121.0  9.5
# 1   35.5  7.0
#
#
#
#
# Results for n_estimators=200, criterion=gini, max_depth=9
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7490
# Average Validation F1 Score: 0.6937
# Average Validation ROC AUC: 0.7347
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  122.0  8.5
# 1   35.5  7.0
#
#
#
#
# Results for n_estimators=200, criterion=gini, max_depth=10
# Average Train Accuracy: 0.9982
# Average Train F1 Score: 0.9982
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7438
# Average Validation F1 Score: 0.6958
# Average Validation ROC AUC: 0.7328
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   33.5   9.0
#
#
#
#
# Results for n_estimators=200, criterion=gini, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7170
# Average Validation F1 Score: 0.6776
# Average Validation ROC AUC: 0.7324
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.5  16.0
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=3
# Average Train Accuracy: 0.8649
# Average Train F1 Score: 0.8691
# Average Train ROC AUC: 0.9578
#
# Average Validation Accuracy: 0.7716
# Average Validation F1 Score: 0.7798
# Average Validation ROC AUC: 0.7696
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  106.0  24.5
# 1   15.0  27.5
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=4
# Average Train Accuracy: 0.8979
# Average Train F1 Score: 0.9008
# Average Train ROC AUC: 0.9759
#
# Average Validation Accuracy: 0.7501
# Average Validation F1 Score: 0.7575
# Average Validation ROC AUC: 0.7653
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  106.0  24.5
# 1   18.5  24.0
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=5
# Average Train Accuracy: 0.9296
# Average Train F1 Score: 0.9313
# Average Train ROC AUC: 0.9903
#
# Average Validation Accuracy: 0.7384
# Average Validation F1 Score: 0.7377
# Average Validation ROC AUC: 0.7565
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  109.0  21.5
# 1   23.5  19.0
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=6
# Average Train Accuracy: 0.9628
# Average Train F1 Score: 0.9635
# Average Train ROC AUC: 0.9968
#
# Average Validation Accuracy: 0.7399
# Average Validation F1 Score: 0.7209
# Average Validation ROC AUC: 0.7470
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.5  16.0
# 1   29.5  13.0
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=7
# Average Train Accuracy: 0.9856
# Average Train F1 Score: 0.9858
# Average Train ROC AUC: 0.9991
#
# Average Validation Accuracy: 0.7483
# Average Validation F1 Score: 0.7305
# Average Validation ROC AUC: 0.7505
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.5  16.0
# 1   28.0  14.5
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=8
# Average Train Accuracy: 0.9928
# Average Train F1 Score: 0.9929
# Average Train ROC AUC: 0.9999
#
# Average Validation Accuracy: 0.7347
# Average Validation F1 Score: 0.7005
# Average Validation ROC AUC: 0.7466
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=9
# Average Train Accuracy: 0.9982
# Average Train F1 Score: 0.9982
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7320
# Average Validation F1 Score: 0.6999
# Average Validation ROC AUC: 0.7407
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.5  14.0
# 1   32.5  10.0
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=10
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7144
# Average Validation F1 Score: 0.6743
# Average Validation ROC AUC: 0.7313
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.0  15.5
# 1   34.0   8.5
#
#
#
#
# Results for n_estimators=200, criterion=entropy, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7523
# Average Validation F1 Score: 0.7044
# Average Validation ROC AUC: 0.7475
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.5  10.0
# 1   33.5   9.0
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=3
# Average Train Accuracy: 0.8627
# Average Train F1 Score: 0.8669
# Average Train ROC AUC: 0.9599
#
# Average Validation Accuracy: 0.7696
# Average Validation F1 Score: 0.7795
# Average Validation ROC AUC: 0.7651
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  105.5  25.0
# 1   14.5  28.0
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=4
# Average Train Accuracy: 0.9037
# Average Train F1 Score: 0.9065
# Average Train ROC AUC: 0.9781
#
# Average Validation Accuracy: 0.7599
# Average Validation F1 Score: 0.7602
# Average Validation ROC AUC: 0.7556
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  110.5  20.0
# 1   21.5  21.0
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=5
# Average Train Accuracy: 0.9350
# Average Train F1 Score: 0.9366
# Average Train ROC AUC: 0.9890
#
# Average Validation Accuracy: 0.7189
# Average Validation F1 Score: 0.7071
# Average Validation ROC AUC: 0.7459
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  109.5  21.0
# 1   27.5  15.0
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=6
# Average Train Accuracy: 0.9704
# Average Train F1 Score: 0.9709
# Average Train ROC AUC: 0.9964
#
# Average Validation Accuracy: 0.7438
# Average Validation F1 Score: 0.7074
# Average Validation ROC AUC: 0.7359
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=7
# Average Train Accuracy: 0.9856
# Average Train F1 Score: 0.9858
# Average Train ROC AUC: 0.9984
#
# Average Validation Accuracy: 0.7209
# Average Validation F1 Score: 0.6853
# Average Validation ROC AUC: 0.7269
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.5  16.0
# 1   32.5  10.0
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=8
# Average Train Accuracy: 0.9928
# Average Train F1 Score: 0.9929
# Average Train ROC AUC: 0.9997
#
# Average Validation Accuracy: 0.7445
# Average Validation F1 Score: 0.6989
# Average Validation ROC AUC: 0.7323
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   34.0   8.5
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=9
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7588
# Average Validation F1 Score: 0.7085
# Average Validation ROC AUC: 0.7323
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  122.0  8.5
# 1   34.0  8.5
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=10
# Average Train Accuracy: 0.9982
# Average Train F1 Score: 0.9982
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7333
# Average Validation F1 Score: 0.6848
# Average Validation ROC AUC: 0.7270
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   35.5   7.0
#
#
#
#
# Results for n_estimators=500, criterion=gini, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7294
# Average Validation F1 Score: 0.6807
# Average Validation ROC AUC: 0.7342
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.0  12.5
# 1   34.5   8.0
#
#
#
#
# Results for n_estimators=500, criterion=entropy, max_depth=3
# Average Train Accuracy: 0.8631
# Average Train F1 Score: 0.8673
# Average Train ROC AUC: 0.9599
#
# Average Validation Accuracy: 0.7637
# Average Validation F1 Score: 0.7765
# Average Validation ROC AUC: 0.7704
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  102.5  28.0
# 1   12.5  30.0
#
#
#
#
# Results for n_estimators=500, criterion=entropy, max_depth=4
# Average Train Accuracy: 0.8957
# Average Train F1 Score: 0.8987
# Average Train ROC AUC: 0.9774
#
# Average Validation Accuracy: 0.7422
# Average Validation F1 Score: 0.7495
# Average Validation ROC AUC: 0.7606
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  106.0  24.5
# 1   19.5  23.0
# Results for n_estimators=500, criterion=entropy, max_depth=5
# Average Train Accuracy: 0.9278
# Average Train F1 Score: 0.9296
# Average Train ROC AUC: 0.9892
#
# Average Validation Accuracy: 0.7456
# Average Validation F1 Score: 0.7436
# Average Validation ROC AUC: 0.7568
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  110.0  20.5
# 1   23.5  19.0
#
#
#
#
# Results for n_estimators=500, criterion=entropy, max_depth=6
# Average Train Accuracy: 0.9632
# Average Train F1 Score: 0.9640
# Average Train ROC AUC: 0.9962
#
# Average Validation Accuracy: 0.7535
# Average Validation F1 Score: 0.7365
# Average Validation ROC AUC: 0.7529
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.0  15.5
# 1   27.5  15.0
#
#
#
#
# Results for n_estimators=500, criterion=entropy, max_depth=7
# Average Train Accuracy: 0.9838
# Average Train F1 Score: 0.9841
# Average Train ROC AUC: 0.9993
#
# Average Validation Accuracy: 0.7464
# Average Validation F1 Score: 0.7144
# Average Validation ROC AUC: 0.7414
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   31.5  11.0
#
#
#
#
# Results for n_estimators=500, criterion=entropy, max_depth=8
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7373
# Average Validation F1 Score: 0.7010
# Average Validation ROC AUC: 0.7386
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.0  13.5
# 1   32.5  10.0
#
#
#
#
# Results for n_estimators=500, criterion=entropy, max_depth=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7314
# Average Validation F1 Score: 0.6952
# Average Validation ROC AUC: 0.7449
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=500, criterion=entropy, max_depth=10
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7190
# Average Validation F1 Score: 0.6802
# Average Validation ROC AUC: 0.7391
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.0  15.5
# 1   33.5   9.0
#
#
#
#
# Results for n_estimators=500, criterion=entropy, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7183
# Average Validation F1 Score: 0.6808
# Average Validation ROC AUC: 0.7418
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.0  16.5
# 1   32.5  10.0
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=3
# Average Train Accuracy: 0.8703
# Average Train F1 Score: 0.8741
# Average Train ROC AUC: 0.9607
#
# Average Validation Accuracy: 0.7455
# Average Validation F1 Score: 0.7589
# Average Validation ROC AUC: 0.7663
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  101.5  29.0
# 1   14.5  28.0
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=4
# Average Train Accuracy: 0.9113
# Average Train F1 Score: 0.9137
# Average Train ROC AUC: 0.9783
#
# Average Validation Accuracy: 0.7449
# Average Validation F1 Score: 0.7481
# Average Validation ROC AUC: 0.7473
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  107.5  23.0
# 1   21.0  21.5
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=5
# Average Train Accuracy: 0.9332
# Average Train F1 Score: 0.9348
# Average Train ROC AUC: 0.9893
#
# Average Validation Accuracy: 0.7359
# Average Validation F1 Score: 0.7174
# Average Validation ROC AUC: 0.7444
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  113.5  17.0
# 1   29.0  13.5
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=6
# Average Train Accuracy: 0.9650
# Average Train F1 Score: 0.9658
# Average Train ROC AUC: 0.9965
#
# Average Validation Accuracy: 0.7223
# Average Validation F1 Score: 0.6918
# Average Validation ROC AUC: 0.7396
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  113.5  17.0
# 1   31.5  11.0
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=7
# Average Train Accuracy: 0.9874
# Average Train F1 Score: 0.9876
# Average Train ROC AUC: 0.9986
#
# Average Validation Accuracy: 0.7249
# Average Validation F1 Score: 0.6861
# Average Validation ROC AUC: 0.7361
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.0  15.5
# 1   32.5  10.0
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=8
# Average Train Accuracy: 0.9928
# Average Train F1 Score: 0.9929
# Average Train ROC AUC: 0.9997
#
# Average Validation Accuracy: 0.7333
# Average Validation F1 Score: 0.6898
# Average Validation ROC AUC: 0.7393
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   33.5   9.0
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=9
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7425
# Average Validation F1 Score: 0.6975
# Average Validation ROC AUC: 0.7371
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=10
# Average Train Accuracy: 0.9964
# Average Train F1 Score: 0.9964
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7523
# Average Validation F1 Score: 0.7033
# Average Validation ROC AUC: 0.7393
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  121.0  9.5
# 1   34.0  8.5
#
#
#
#
# Results for n_estimators=1000, criterion=gini, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7359
# Average Validation F1 Score: 0.6859
# Average Validation ROC AUC: 0.7319
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   34.5   8.0
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=3
# Average Train Accuracy: 0.8649
# Average Train F1 Score: 0.8691
# Average Train ROC AUC: 0.9591
#
# Average Validation Accuracy: 0.7670
# Average Validation F1 Score: 0.7787
# Average Validation ROC AUC: 0.7686
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  103.5  27.0
# 1   13.0  29.5
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=4
# Average Train Accuracy: 0.8939
# Average Train F1 Score: 0.8970
# Average Train ROC AUC: 0.9778
#
# Average Validation Accuracy: 0.7553
# Average Validation F1 Score: 0.7620
# Average Validation ROC AUC: 0.7621
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  107.0  23.5
# 1   18.5  24.0
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=5
# Average Train Accuracy: 0.9278
# Average Train F1 Score: 0.9297
# Average Train ROC AUC: 0.9896
#
# Average Validation Accuracy: 0.7293
# Average Validation F1 Score: 0.7322
# Average Validation ROC AUC: 0.7527
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  106.5  24.0
# 1   22.5  20.0
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=6
# Average Train Accuracy: 0.9632
# Average Train F1 Score: 0.9641
# Average Train ROC AUC: 0.9966
#
# Average Validation Accuracy: 0.7516
# Average Validation F1 Score: 0.7322
# Average Validation ROC AUC: 0.7475
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   28.5  14.0
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=7
# Average Train Accuracy: 0.9874
# Average Train F1 Score: 0.9876
# Average Train ROC AUC: 0.9992
#
# Average Validation Accuracy: 0.7203
# Average Validation F1 Score: 0.6943
# Average Validation ROC AUC: 0.7445
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  113.0  17.5
# 1   31.0  11.5
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=8
# Average Train Accuracy: 0.9946
# Average Train F1 Score: 0.9946
# Average Train ROC AUC: 0.9999
#
# Average Validation Accuracy: 0.7256
# Average Validation F1 Score: 0.6936
# Average Validation ROC AUC: 0.7536
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.5  16.0
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7373
# Average Validation F1 Score: 0.7020
# Average Validation ROC AUC: 0.7516
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.5  14.0
# 1   32.0  10.5
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=10
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7458
# Average Validation F1 Score: 0.7036
# Average Validation ROC AUC: 0.7512
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.0   9.5
#
#
#
#
# Results for n_estimators=1000, criterion=entropy, max_depth=11
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7347
# Average Validation F1 Score: 0.6922
# Average Validation ROC AUC: 0.7467
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   33.5   9.0
#
#
#
#
# Best Average F1: 0.7913
# Best Average ROC: 0.7563
# Best Model Parameters:
# {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 3}
# Best Confusion Matrix:
# [[108.5  22. ]
#  [ 15.   27.5]]

# %% [markdown]
# {'n_estimators': 200, 'criterion': 'entropy', 'max_depth': 3}
# {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 3}

# %%
train_val_years = [2015, 2016, 2017]

# logic_params = {
#     'penalty': ['l1', 'l2'],
#     'C': [1, 10, 20, 50, 100, 200, 500, 1000]
# }

logic_params = {
    'penalty': ['l1', 'l2'],
    'C': [100, 2000, 3000, 4000, 5000, 6000, 7000]
}

# best_f1_roc = 0     # The harmonic mean of F1 and ROC AUC Scores is best
best_avg_f1 = 0
best_params = {}

for pen in logic_params['penalty']:
    for c in logic_params['C']:
        model = LogisticRegression(
            penalty=pen,
            tol=0.0001,
            C=c,
            fit_intercept=True,
            class_weight='balanced',
            solver='liblinear',
            max_iter=1000
        )

        train_acc = []
        train_f1 = []
        train_roc = []

        val_acc = []
        val_f1 = []
        val_roc = []

        f1_roc = []

        conf_matrix = np.zeros(shape=(2, 2))

        for i in range(len(train_val_years)-1):
            X_train = data[data.index.year <= train_val_years[i]].values
            X_val = data[data.index.year == train_val_years[i+1]].values

            y_train = labels[labels.index.year <= train_val_years[i]].values
            y_val = labels[labels.index.year == train_val_years[i+1]].values

            y_train = np.reshape(y_train.astype(int), newshape=(X_train.shape[0]))
            y_val = np.reshape(y_val.astype(int), newshape=(X_val.shape[0]))

            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)
            y_prob = model.predict_proba(X_val)[:, 1]

            train_acc.append(model.score(X_train, y_train))
            train_f1.append(f1_score(y_train, model.predict(X_train), average='weighted'))
            train_roc.append(roc_auc_score(y_train, model.predict_proba(X_train)[:, 1], average='weighted'))

            val_acc.append(model.score(X_val, y_val))
            val_f1.append(f1_score(y_val, y_pred, average='weighted'))
            val_roc.append(roc_auc_score(y_val, y_prob, average='weighted'))

            conf_matrix += confusion_matrix(y_val, y_pred)

            f1_roc.append(np.sqrt(val_roc[i] * val_f1[i]))

        avg_train_acc = sum(train_acc) / (len(train_val_years)-1)
        avg_train_f1 = sum(train_f1) / (len(train_val_years)-1)
        avg_train_roc = sum(train_roc) / (len(train_val_years)-1)

        avg_val_acc = sum(val_acc) / (len(train_val_years)-1)
        avg_val_f1 = sum(val_f1) / (len(train_val_years)-1)
        avg_val_roc = sum(val_roc) / (len(train_val_years)-1)

        conf_matrix /= (len(train_val_years)-1)

#         avg_f1_roc = sum(f1_roc) / (len(train_val_years)-1)

        if avg_val_f1 > best_avg_f1:
            best_params['penalty'] = pen
            best_params['C'] = c
            best_conf_matrix = conf_matrix
            best_avg_f1 = avg_val_f1
            best_avg_roc = avg_val_roc

        print('Results for penalty=' + str(pen) + ', C=' + str(c))
        print('Average Train Accuracy: %0.4f' % avg_train_acc)
        print('Average Train F1 Score: %0.4f' % avg_train_f1)
        print('Average Train ROC AUC: %0.4f\n' % avg_train_roc)

        print('Average Validation Accuracy: %0.4f' % avg_val_acc)
        print('Average Validation F1 Score: %0.4f' % avg_val_f1)
        print('Average Validation ROC AUC: %0.4f' % avg_val_roc)
        print()
#         print('Average Harmonic Mean of F1 Score and ROC AUC Score: %0.4f' % avg_f1_roc)

        print('\nAverage Confusion Matrix:\n')
        print(pd.DataFrame(conf_matrix))
        print('\n\n\n')
            
# print('Best Average F1-ROC AUC Score: %0.4f' % best_f1_roc)
print('Best Average F1: %0.4f ' % best_avg_f1)
print('Best Average ROC: %0.4f ' % best_avg_roc)
print('Best Model Parameters:')
print(best_params)
print('Best Confusion Matrix:')
print(best_conf_matrix)
print('\n\n\n')
# Out:
# Results for penalty=l1, C=100
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8906
# Average Train ROC AUC: 0.9412
#
# Average Validation Accuracy: 0.6254
# Average Validation F1 Score: 0.6402
# Average Validation ROC AUC: 0.5508
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  94.5  36.0
# 1  26.5  16.0
#
#
#
#
# Results for penalty=l1, C=2000
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8906
# Average Train ROC AUC: 0.9412
#
# Average Validation Accuracy: 0.6398
# Average Validation F1 Score: 0.6535
# Average Validation ROC AUC: 0.5622
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  95.5  35.0
# 1  25.5  17.0
#
#
#
#
# Results for penalty=l1, C=3000
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8906
# Average Train ROC AUC: 0.9412
#
# Average Validation Accuracy: 0.6424
# Average Validation F1 Score: 0.6557
# Average Validation ROC AUC: 0.5625
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  96.0  34.5
# 1  25.5  17.0
#
#
#
#
# Results for penalty=l1, C=4000
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8906
# Average Train ROC AUC: 0.9412
#
# Average Validation Accuracy: 0.6300
# Average Validation F1 Score: 0.6446
# Average Validation ROC AUC: 0.5607
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  95.0  35.5
# 1  26.5  16.0
#
#
#
#
# Results for penalty=l1, C=5000
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8906
# Average Train ROC AUC: 0.9412
#
# Average Validation Accuracy: 0.6398
# Average Validation F1 Score: 0.6535
# Average Validation ROC AUC: 0.5621
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  95.5  35.0
# 1  25.5  17.0
#
#
#
#
# Results for penalty=l1, C=6000
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8906
# Average Train ROC AUC: 0.9410
#
# Average Validation Accuracy: 0.6300
# Average Validation F1 Score: 0.6446
# Average Validation ROC AUC: 0.5610
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  95.0  35.5
# 1  26.5  16.0
#
#
#
#
# Results for penalty=l1, C=7000
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8906
# Average Train ROC AUC: 0.9412
#
# Average Validation Accuracy: 0.6300
# Average Validation F1 Score: 0.6446
# Average Validation ROC AUC: 0.5616
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  95.0  35.5
# 1  26.5  16.0
#
#
#
#
# Results for penalty=l2, C=100
# Average Train Accuracy: 0.8809
# Average Train F1 Score: 0.8845
# Average Train ROC AUC: 0.9418
#
# Average Validation Accuracy: 0.5345
# Average Validation F1 Score: 0.5406
# Average Validation ROC AUC: 0.5222
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  77.0  53.5
# 1  23.0  19.5
#
#
#
#
# Results for penalty=l2, C=2000
# Average Train Accuracy: 0.8791
# Average Train F1 Score: 0.8829
# Average Train ROC AUC: 0.9416
#
# Average Validation Accuracy: 0.5320
# Average Validation F1 Score: 0.5384
# Average Validation ROC AUC: 0.5276
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  76.5  54.0
# 1  23.0  19.5
#
#
#
#
# Results for penalty=l2, C=3000
# Average Train Accuracy: 0.8849
# Average Train F1 Score: 0.8885
# Average Train ROC AUC: 0.9418
#
# Average Validation Accuracy: 0.5320
# Average Validation F1 Score: 0.5384
# Average Validation ROC AUC: 0.5259
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  76.5  54.0
# 1  23.0  19.5
#
#
#
#
# Results for penalty=l2, C=4000
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8908
# Average Train ROC AUC: 0.9417
#
# Average Validation Accuracy: 0.5443
# Average Validation F1 Score: 0.5558
# Average Validation ROC AUC: 0.5269
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  79.5  51.0
# 1  24.0  18.5
#
#
#
#
# Results for penalty=l2, C=5000
# Average Train Accuracy: 0.8769
# Average Train F1 Score: 0.8806
# Average Train ROC AUC: 0.9422
#
# Average Validation Accuracy: 0.5320
# Average Validation F1 Score: 0.5384
# Average Validation ROC AUC: 0.5235
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  76.5  54.0
# 1  23.0  19.5
#
#
#
#
# Results for penalty=l2, C=6000
# Average Train Accuracy: 0.8871
# Average Train F1 Score: 0.8908
# Average Train ROC AUC: 0.9419
#
# Average Validation Accuracy: 0.5404
# Average Validation F1 Score: 0.5485
# Average Validation ROC AUC: 0.5227
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  78.5  52.0
# 1  23.5  19.0
#
#
#
#
# Results for penalty=l2, C=7000
# Average Train Accuracy: 0.8791
# Average Train F1 Score: 0.8829
# Average Train ROC AUC: 0.9416
#
# Average Validation Accuracy: 0.5345
# Average Validation F1 Score: 0.5406
# Average Validation ROC AUC: 0.5229
#
#
# Average Confusion Matrix:
#
#       0     1
# 0  77.0  53.5
# 1  23.0  19.5
#
#
#
#
# Best Average F1: 0.6557
# Best Average ROC: 0.5625
# Best Model Parameters:
# {'penalty': 'l1', 'C': 3000}
# Best Confusion Matrix:
# [[96.  34.5]
#  [25.5 17. ]]

# %% [markdown]
# 0.8512: {'penalty': 'l1', 'C': 1000}
# 0.8526: {'penalty': 'l1', 'C': 1000}
# 0.8596: {'penalty': 'l1', 'C': 5000}
# 0.8593: {'penalty': 'l1', 'C': 10000}
# 0.8442: {'penalty': 'l1', 'C': 5000}
#
# Only using F1
# 0.8074: {'penalty': 'l1', 'C': 4000}
# 0.8102: {'penalty': 'l1', 'C': 3000}
# 0.8102: {'penalty': 'l1', 'C': 3000}

# %%
train_val_years = [2015, 2016, 2017]

svc_params = {
    'C': [1, 10, 20, 50, 100, 200, 500, 1000],
    'kernel': ['poly', 'rbf'],
    'degree': [3, 4, 5, 6, 7, 8, 9]
}

# best_f1_roc = 0     # The harmonic mean of F1 and ROC AUC Scores is best
best_avg_f1 = 0
best_params = {}

for c in svc_params['C']:
    for k in svc_params['kernel']:
        if k == 'poly':
            for d in svc_params['degree']:
                svc = SVC(                     # gives even slightly fewer false negatives than logic
                    C=c,
                    kernel=k,
                    degree=6,
                    gamma='auto',
                    coef0=1,
                    probability=True,
                    tol=0.001,
                    class_weight='balanced',
                    max_iter=10000
                )

                train_acc = []
                train_f1 = []
                train_roc = []

                val_acc = []
                val_f1 = []
                val_roc = []

                f1_roc = []

                conf_matrix = np.zeros(shape=(2, 2))

                for i in range(len(train_val_years)-1):
                    X_train = data[data.index.year <= train_val_years[i]].values
                    X_val = data[data.index.year == train_val_years[i+1]].values

                    y_train = labels[labels.index.year <= train_val_years[i]].values
                    y_val = labels[labels.index.year == train_val_years[i+1]].values

                    y_train = np.reshape(y_train.astype(int), newshape=(X_train.shape[0]))
                    y_val = np.reshape(y_val.astype(int), newshape=(X_val.shape[0]))

                    model.fit(X_train, y_train)
                    y_pred = model.predict(X_val)
                    y_prob = model.predict_proba(X_val)[:, 1]

                    train_acc.append(model.score(X_train, y_train))
                    train_f1.append(f1_score(y_train, model.predict(X_train), average='weighted'))
                    train_roc.append(roc_auc_score(y_train, model.predict_proba(X_train)[:, 1], average='weighted'))

                    val_acc.append(model.score(X_val, y_val))
                    val_f1.append(f1_score(y_val, y_pred, average='weighted'))
                    val_roc.append(roc_auc_score(y_val, y_prob, average='weighted'))

                    conf_matrix += confusion_matrix(y_val, y_pred)

                    f1_roc.append(np.sqrt(val_roc[i] * val_f1[i]))

                avg_train_acc = sum(train_acc) / (len(train_val_years)-1)
                avg_train_f1 = sum(train_f1) / (len(train_val_years)-1)
                avg_train_roc = sum(train_roc) / (len(train_val_years)-1)

                avg_val_acc = sum(val_acc) / (len(train_val_years)-1)
                avg_val_f1 = sum(val_f1) / (len(train_val_years)-1)
                avg_val_roc = sum(val_roc) / (len(train_val_years)-1)

                conf_matrix /= (len(train_val_years)-1)

        #         avg_f1_roc = sum(f1_roc) / (len(train_val_years)-1)

                if avg_val_f1 > best_avg_f1:
                    best_params['C'] = c
                    best_params['kernel'] = k
                    best_params['degree'] = d
                    best_conf_matrix = conf_matrix
                    best_avg_f1 = avg_val_f1
                    best_avg_roc = avg_val_roc

                print('Results for C=' + str(c) + ', kernel=' + str(k) + ', degree=' + str(d))
                print('Average Train Accuracy: %0.4f' % avg_train_acc)
                print('Average Train F1 Score: %0.4f' % avg_train_f1)
                print('Average Train ROC AUC: %0.4f\n' % avg_train_roc)

                print('Average Validation Accuracy: %0.4f' % avg_val_acc)
                print('Average Validation F1 Score: %0.4f' % avg_val_f1)
                print('Average Validation ROC AUC: %0.4f' % avg_val_roc)
                print()
        #         print('Average Harmonic Mean of F1 Score and ROC AUC Score: %0.4f' % avg_f1_roc)

                print('\nAverage Confusion Matrix:\n')
                print(pd.DataFrame(conf_matrix))
                print('\n\n\n')   
        else:
            svc = SVC(                     # gives even slightly fewer false negatives than logic
                C=c,
                kernel=k,
                gamma='auto',
                coef0=1,
                probability=True,
                tol=0.001,
                class_weight='balanced',
                max_iter=10000
            )

            train_acc = []
            train_f1 = []
            train_roc = []

            val_acc = []
            val_f1 = []
            val_roc = []

            f1_roc = []

            conf_matrix = np.zeros(shape=(2, 2))

            for i in range(len(train_val_years)-1):
                X_train = data[data.index.year <= train_val_years[i]].values
                X_val = data[data.index.year == train_val_years[i+1]].values

                y_train = labels[labels.index.year <= train_val_years[i]].values
                y_val = labels[labels.index.year == train_val_years[i+1]].values

                y_train = np.reshape(y_train.astype(int), newshape=(X_train.shape[0]))
                y_val = np.reshape(y_val.astype(int), newshape=(X_val.shape[0]))

                model.fit(X_train, y_train)
                y_pred = model.predict(X_val)
                y_prob = model.predict_proba(X_val)[:, 1]

                train_acc.append(model.score(X_train, y_train))
                train_f1.append(f1_score(y_train, model.predict(X_train), average='weighted'))
                train_roc.append(roc_auc_score(y_train, model.predict_proba(X_train)[:, 1], average='weighted'))

                val_acc.append(model.score(X_val, y_val))
                val_f1.append(f1_score(y_val, y_pred, average='weighted'))
                val_roc.append(roc_auc_score(y_val, y_prob, average='weighted'))

                conf_matrix += confusion_matrix(y_val, y_pred)

                f1_roc.append(np.sqrt(val_roc[i] * val_f1[i]))

            avg_train_acc = sum(train_acc) / (len(train_val_years)-1)
            avg_train_f1 = sum(train_f1) / (len(train_val_years)-1)
            avg_train_roc = sum(train_roc) / (len(train_val_years)-1)

            avg_val_acc = sum(val_acc) / (len(train_val_years)-1)
            avg_val_f1 = sum(val_f1) / (len(train_val_years)-1)
            avg_val_roc = sum(val_roc) / (len(train_val_years)-1)

            conf_matrix /= (len(train_val_years)-1)

    #         avg_f1_roc = sum(f1_roc) / (len(train_val_years)-1)

            if avg_val_f1 > best_avg_f1:
                best_params['C'] = c
                best_params['kernel'] = k
                best_params['degree'] = None
                best_conf_matrix = conf_matrix
                best_avg_f1 = avg_val_f1
                best_avg_roc = avg_val_roc

            print('Results for C=' + str(c) + ', kernel=' + str(k) + ', degree=None')
            print('Average Train Accuracy: %0.4f' % avg_train_acc)
            print('Average Train F1 Score: %0.4f' % avg_train_f1)
            print('Average Train ROC AUC: %0.4f\n' % avg_train_roc)

            print('Average Validation Accuracy: %0.4f' % avg_val_acc)
            print('Average Validation F1 Score: %0.4f' % avg_val_f1)
            print('Average Validation ROC AUC: %0.4f' % avg_val_roc)
            print()
    #         print('Average Harmonic Mean of F1 Score and ROC AUC Score: %0.4f' % avg_f1_roc)

            print('\nAverage Confusion Matrix:\n')
            print(pd.DataFrame(conf_matrix))
            print('\n\n\n')
            
# print('Best Average F1-ROC AUC Score: %0.4f' % best_f1_roc)
print('Best Average F1: %0.4f ' % best_avg_f1)
print('Best Average ROC: %0.4f ' % best_avg_roc)
print('Best Model Parameters:')
print(best_params)
print('Best Confusion Matrix:')
print(best_conf_matrix)
print('\n\n\n')
# Out:
# Results for C=1, kernel=poly, degree=3
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7569
# Average Validation F1 Score: 0.7083
# Average Validation ROC AUC: 0.7461
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  121.5  9.0
# 1   34.0  8.5
#
#
#
#
# Results for C=1, kernel=poly, degree=4
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7216
# Average Validation F1 Score: 0.6817
# Average Validation ROC AUC: 0.7434
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   33.5   9.0
#
#
#
#
# Results for C=1, kernel=poly, degree=5
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7327
# Average Validation F1 Score: 0.6887
# Average Validation ROC AUC: 0.7380
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   33.5   9.0
#
#
#
#
# Results for C=1, kernel=poly, degree=6
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7490
# Average Validation F1 Score: 0.7029
# Average Validation ROC AUC: 0.7488
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   33.0   9.5
#
#
#
#
# Results for C=1, kernel=poly, degree=7
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7307
# Average Validation F1 Score: 0.6873
# Average Validation ROC AUC: 0.7489
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   34.0   8.5
#
#
#
#
# Results for C=1, kernel=poly, degree=8
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7301
# Average Validation F1 Score: 0.6850
# Average Validation ROC AUC: 0.7428
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.0  12.5
# 1   34.5   8.0
#
#
#
#
# Results for C=1, kernel=poly, degree=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7438
# Average Validation F1 Score: 0.6989
# Average Validation ROC AUC: 0.7518
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   33.5   9.0
#
#
#
#
# Results for C=1, kernel=rbf, degree=None
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7445
# Average Validation F1 Score: 0.7001
# Average Validation ROC AUC: 0.7509
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   33.5   9.0
#
#
#
#
# Results for C=10, kernel=poly, degree=3
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7445
# Average Validation F1 Score: 0.7012
# Average Validation ROC AUC: 0.7471
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.0   9.5
#
#
#
#
# Results for C=10, kernel=poly, degree=4
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7445
# Average Validation F1 Score: 0.7012
# Average Validation ROC AUC: 0.7469
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.0   9.5
#
#
#
#
# Results for C=10, kernel=poly, degree=5
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7445
# Average Validation F1 Score: 0.7012
# Average Validation ROC AUC: 0.7467
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.0   9.5
#
#
#
#
# Results for C=10, kernel=poly, degree=6
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7235
# Average Validation F1 Score: 0.6786
# Average Validation ROC AUC: 0.7441
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   35.0   7.5
#
#
#
#
# Results for C=10, kernel=poly, degree=7
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7503
# Average Validation F1 Score: 0.7042
# Average Validation ROC AUC: 0.7443
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   33.5   9.0
#
#
#
#
# Results for C=10, kernel=poly, degree=8
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7249
# Average Validation F1 Score: 0.6843
# Average Validation ROC AUC: 0.7490
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   33.5   9.0
#
#
#
#
# Results for C=10, kernel=poly, degree=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7151
# Average Validation F1 Score: 0.6764
# Average Validation ROC AUC: 0.7403
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  114.5  16.0
# 1   33.5   9.0
#
#
#
#
# Results for C=10, kernel=rbf, degree=None
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7569
# Average Validation F1 Score: 0.7095
# Average Validation ROC AUC: 0.7471
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  121.0  9.5
# 1   33.5  9.0
#
#
#
#
# Results for C=20, kernel=poly, degree=3
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7235
# Average Validation F1 Score: 0.6829
# Average Validation ROC AUC: 0.7392
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   33.0   9.5
#
#
#
#
# Results for C=20, kernel=poly, degree=4
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7471
# Average Validation F1 Score: 0.7015
# Average Validation ROC AUC: 0.7500
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   33.5   9.0
#
#
#
#
# Results for C=20, kernel=poly, degree=5
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7242
# Average Validation F1 Score: 0.6831
# Average Validation ROC AUC: 0.7411
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   33.5   9.0
#
#
#
#
# Results for C=20, kernel=poly, degree=6
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7471
# Average Validation F1 Score: 0.7054
# Average Validation ROC AUC: 0.7464
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   33.0   9.5
#
#
#
#
# Results for C=20, kernel=poly, degree=7
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7529
# Average Validation F1 Score: 0.7067
# Average Validation ROC AUC: 0.7492
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   33.0   9.5
#
#
#
#
# Results for C=20, kernel=poly, degree=8
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7373
# Average Validation F1 Score: 0.6936
# Average Validation ROC AUC: 0.7411
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.0  12.5
# 1   33.5   9.0
#
#
#
#
# Results for C=20, kernel=poly, degree=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7314
# Average Validation F1 Score: 0.6906
# Average Validation ROC AUC: 0.7486
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.5  14.0
# 1   33.0   9.5
#
#
#
#
# Results for C=20, kernel=rbf, degree=None
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7536
# Average Validation F1 Score: 0.7069
# Average Validation ROC AUC: 0.7478
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.5  10.0
# 1   33.5   9.0
#
#
#
#
# Results for C=50, kernel=poly, degree=3
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7242
# Average Validation F1 Score: 0.6849
# Average Validation ROC AUC: 0.7452
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.0  15.5
# 1   32.5  10.0
#
#
#
#
# Results for C=50, kernel=poly, degree=4
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7295
# Average Validation F1 Score: 0.6903
# Average Validation ROC AUC: 0.7515
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   33.0   9.5
# Results for C=50, kernel=poly, degree=5
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7314
# Average Validation F1 Score: 0.6885
# Average Validation ROC AUC: 0.7480
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   34.0   8.5
#
#
#
#
# Results for C=50, kernel=poly, degree=6
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7562
# Average Validation F1 Score: 0.7083
# Average Validation ROC AUC: 0.7495
#
#
# Average Confusion Matrix:
#
#        0    1
# 0  121.0  9.5
# 1   33.5  9.0
#
#
#
#
# Results for C=50, kernel=poly, degree=7
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7386
# Average Validation F1 Score: 0.6948
# Average Validation ROC AUC: 0.7426
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   34.0   8.5
#
#
#
#
# Results for C=50, kernel=poly, degree=8
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7503
# Average Validation F1 Score: 0.7042
# Average Validation ROC AUC: 0.7481
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   33.5   9.0
#
#
#
#
# Results for C=50, kernel=poly, degree=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7281
# Average Validation F1 Score: 0.6879
# Average Validation ROC AUC: 0.7417
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   33.0   9.5
#
#
#
#
# Results for C=50, kernel=rbf, degree=None
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7497
# Average Validation F1 Score: 0.7018
# Average Validation ROC AUC: 0.7410
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.5  10.0
# 1   34.0   8.5
#
#
#
#
# Results for C=100, kernel=poly, degree=3
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7340
# Average Validation F1 Score: 0.6925
# Average Validation ROC AUC: 0.7428
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.0  12.5
# 1   34.0   8.5
#
#
#
#
# Results for C=100, kernel=poly, degree=4
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7569
# Average Validation F1 Score: 0.7107
# Average Validation ROC AUC: 0.7469
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.5  10.0
# 1   33.0   9.5
#
#
#
#
# Results for C=100, kernel=poly, degree=5
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7503
# Average Validation F1 Score: 0.7042
# Average Validation ROC AUC: 0.7490
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   33.5   9.0
#
#
#
#
# Results for C=100, kernel=poly, degree=6
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7235
# Average Validation F1 Score: 0.6820
# Average Validation ROC AUC: 0.7407
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   33.5   9.0
#
#
#
#
# Results for C=100, kernel=poly, degree=7
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7197
# Average Validation F1 Score: 0.6803
# Average Validation ROC AUC: 0.7406
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   34.0   8.5
#
#
#
#
# Results for C=100, kernel=poly, degree=8
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7438
# Average Validation F1 Score: 0.7027
# Average Validation ROC AUC: 0.7468
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.0   9.5
#
#
#
#
# Results for C=100, kernel=poly, degree=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7569
# Average Validation F1 Score: 0.7117
# Average Validation ROC AUC: 0.7510
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   32.5  10.0
#
#
#
#
# Results for C=100, kernel=rbf, degree=None
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7307
# Average Validation F1 Score: 0.6894
# Average Validation ROC AUC: 0.7496
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.5  14.0
# 1   33.0   9.5
#
#
#
#
# Results for C=200, kernel=poly, degree=3
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7340
# Average Validation F1 Score: 0.6958
# Average Validation ROC AUC: 0.7402
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.5  14.0
# 1   32.5  10.0
#
#
#
#
# Results for C=200, kernel=poly, degree=4
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7412
# Average Validation F1 Score: 0.6963
# Average Validation ROC AUC: 0.7476
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   34.0   8.5
#
#
#
#
# Results for C=200, kernel=poly, degree=5
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7405
# Average Validation F1 Score: 0.6963
# Average Validation ROC AUC: 0.7490
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.5   9.0
#
#
#
#
# Results for C=200, kernel=poly, degree=6
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7405
# Average Validation F1 Score: 0.6973
# Average Validation ROC AUC: 0.7436
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.0  12.5
# 1   33.0   9.5
#
#
#
#
# Results for C=200, kernel=poly, degree=7
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7529
# Average Validation F1 Score: 0.7056
# Average Validation ROC AUC: 0.7414
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.5  10.0
# 1   33.5   9.0
#
#
#
#
# Results for C=200, kernel=poly, degree=8
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7203
# Average Validation F1 Score: 0.6802
# Average Validation ROC AUC: 0.7409
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.0  15.5
# 1   33.0   9.5
#
#
#
#
# Results for C=200, kernel=poly, degree=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7216
# Average Validation F1 Score: 0.6817
# Average Validation ROC AUC: 0.7453
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  115.5  15.0
# 1   33.5   9.0
#
#
#
#
# Results for C=200, kernel=rbf, degree=None
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7340
# Average Validation F1 Score: 0.6920
# Average Validation ROC AUC: 0.7534
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.0  13.5
# 1   33.0   9.5
#
#
#
#
# Results for C=500, kernel=poly, degree=3
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7445
# Average Validation F1 Score: 0.7001
# Average Validation ROC AUC: 0.7406
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   33.5   9.0
#
#
#
#
# Results for C=500, kernel=poly, degree=4
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7497
# Average Validation F1 Score: 0.7041
# Average Validation ROC AUC: 0.7534
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   33.0   9.5
#
#
#
#
# Results for C=500, kernel=poly, degree=5
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7497
# Average Validation F1 Score: 0.7030
# Average Validation ROC AUC: 0.7441
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   33.5   9.0
#
#
#
#
# Results for C=500, kernel=poly, degree=6
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7399
# Average Validation F1 Score: 0.6961
# Average Validation ROC AUC: 0.7469
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.0  12.5
# 1   33.0   9.5
# Results for C=500, kernel=poly, degree=7
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7471
# Average Validation F1 Score: 0.7015
# Average Validation ROC AUC: 0.7471
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   33.5   9.0
#
#
#
#
# Results for C=500, kernel=poly, degree=8
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7333
# Average Validation F1 Score: 0.6908
# Average Validation ROC AUC: 0.7542
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.0  13.5
# 1   33.0   9.5
#
#
#
#
# Results for C=500, kernel=poly, degree=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7471
# Average Validation F1 Score: 0.7004
# Average Validation ROC AUC: 0.7465
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.0  10.5
# 1   34.0   8.5
#
#
#
#
# Results for C=500, kernel=rbf, degree=None
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7438
# Average Validation F1 Score: 0.7000
# Average Validation ROC AUC: 0.7473
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.0   9.5
#
#
#
#
# Results for C=1000, kernel=poly, degree=3
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7405
# Average Validation F1 Score: 0.6990
# Average Validation ROC AUC: 0.7524
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  118.5  12.0
# 1   33.5   9.0
#
#
#
#
# Results for C=1000, kernel=poly, degree=4
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7602
# Average Validation F1 Score: 0.7144
# Average Validation ROC AUC: 0.7500
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  120.5  10.0
# 1   32.5  10.0
#
#
#
#
# Results for C=1000, kernel=poly, degree=5
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7209
# Average Validation F1 Score: 0.6795
# Average Validation ROC AUC: 0.7423
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   34.0   8.5
#
#
#
#
# Results for C=1000, kernel=poly, degree=6
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7281
# Average Validation F1 Score: 0.6907
# Average Validation ROC AUC: 0.7430
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  116.0  14.5
# 1   33.0   9.5
#
#
#
#
# Results for C=1000, kernel=poly, degree=7
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7445
# Average Validation F1 Score: 0.6989
# Average Validation ROC AUC: 0.7464
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.5  11.0
# 1   34.0   8.5
#
#
#
#
# Results for C=1000, kernel=poly, degree=8
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7373
# Average Validation F1 Score: 0.6947
# Average Validation ROC AUC: 0.7500
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.5  13.0
# 1   33.0   9.5
#
#
#
#
# Results for C=1000, kernel=poly, degree=9
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7438
# Average Validation F1 Score: 0.6989
# Average Validation ROC AUC: 0.7483
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  119.0  11.5
# 1   33.5   9.0
#
#
#
#
# Results for C=1000, kernel=rbf, degree=None
# Average Train Accuracy: 1.0000
# Average Train F1 Score: 1.0000
# Average Train ROC AUC: 1.0000
#
# Average Validation Accuracy: 0.7307
# Average Validation F1 Score: 0.6884
# Average Validation ROC AUC: 0.7455
#
#
# Average Confusion Matrix:
#
#        0     1
# 0  117.0  13.5
# 1   33.5   9.0
#
#
#
#
# Best Average F1: 0.7144
# Best Average ROC: 0.7500
# Best Model Parameters:
# {'C': 1000, 'kernel': 'poly', 'degree': 4}
# Best Confusion Matrix:
# [[120.5  10. ]
#  [ 32.5  10. ]]

# %% [markdown]
# 0.5944: {'C': 1, 'kernel': 'poly', 'degree': 3}
# 0.5944: {'C': 1, 'kernel': 'poly', 'degree': 3}

# %% [markdown]
# ### Predict on 2018

# %%
best_rfc = RandomForestClassifier(
    n_estimators=200,
    max_depth=3,
    criterion='entropy',
    bootstrap=True,
    class_weight='balanced'
)

best_logic = LogisticRegression(
    penalty='l1',
    tol=0.0001,
    C=5000,
    fit_intercept=True,
    class_weight='balanced',
    solver='liblinear',
    max_iter=1000
)

best_svc = SVC(                     # gives even slightly fewer false negatives than logic
    C=1000,
    kernel='poly',
    degree=4,
    gamma='auto',
    coef0=1,
    probability=True,
    tol=0.001,
    class_weight='balanced',
    max_iter=10000
)

gnb = GaussianNB(
    var_smoothing=1e-9
)

# best_rfc = RandomForestClassifier(
#     n_estimators=20,
#     max_depth=3,
#     criterion='entropy',
#     bootstrap=True,
#     class_weight='balanced'
# )

best_model = gnb

# %%
X_train = data[data.index.year < 2018].values
X_test = data[data.index.year == 2018].values

y_train = labels[labels.index.year < 2018].values
y_test = labels[labels.index.year == 2018].values

y_train = np.reshape(y_train.astype(int), newshape=(X_train.shape[0]))
y_test = np.reshape(y_test.astype(int), newshape=(X_test.shape[0]))

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)
y_prob = best_model.predict_proba(X_test)[:, 1]

train_acc = best_model.score(X_train, y_train)
train_f1 = f1_score(y_train, best_model.predict(X_train), average='weighted')
train_roc = roc_auc_score(y_train, best_model.predict_proba(X_train)[:, 1], average='weighted')

test_acc = best_model.score(X_test, y_test)
test_f1 = f1_score(y_test, y_pred, average='weighted')
test_roc = roc_auc_score(y_test, y_prob, average='weighted')

conf_matrix = confusion_matrix(y_test, y_pred)

print('Train Accuracy: %0.4f' % train_acc)
print('Train F1 Score: %0.4f' % train_f1)
print('Train ROC AUC: %0.4f\n' % train_roc)

print('Test Accuracy: %0.4f' % test_acc)
print('Test F1 Score: %0.4f' % test_f1)
print('Test ROC AUC: %0.4f' % test_roc)

print('\nAverage Confusion Matrix:\n')
print(pd.DataFrame(conf_matrix))
print('\n\n\n')
# Out:
# Train Accuracy: 0.7797
# Train F1 Score: 0.7884
# Train ROC AUC: 0.8267
#
# Test Accuracy: 0.6962
# Test F1 Score: 0.6941
# Test ROC AUC: 0.7449
#
# Average Confusion Matrix:
#
#     0   1
# 0  48  30
# 1  18  62

# %%
max_feat_idx = np.argsort(-abs(best_model.coef_[0]), kind='mergesort')
abs(best_model.coef_[0, max_feat_idx])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-f2c8f6b005cc> in <module>()
# ----> 1 max_feat_idx = np.argsort(-abs(best_model.coef_[0]), kind='mergesort')
#       2 abs(best_model.coef_[0, max_feat_idx])
#
# AttributeError: 'GaussianNB' object has no attribute 'coef_'

# %%
data.columns.values[max_feat_idx]
# Out:
# array(['do_raw', 'do_sat', 'cos_month', 'DAILYMinimumDryBulbTemp',
#        'DAILYDeptFromNormalAverageTemp', 'algalBloomSheen_one_week',
#        'air_temp', 'DAILYAverageDryBulbTemp', 'algalBloomSheen_one_day',
#        'DAILYAverageDewPointTemp', 'sin_month', 'par_below',
#        'DAILYMaximumDryBulbTemp', 'do_wtemp', 'DAILYPrecip_one_week',
#        'algalBloomSheen_three_day', 'DAILYPrecip', 'DAILYPrecip_one_day',
#        'par', 'DAILYAverageSeaLevelPressure', 'DAILYPrecip_three_day',
#        'pco2_ppm', 'rel_hum', 'turbidity', 'phycocyanin',
#        'DAILYAverageWetBulbTemp', 'cos_wind_dir', 'chlor', 'sin_wind_dir',
#        'DAILYAverageStationPressure', 'wind_speed'], dtype=object)

# %% [markdown]
# ### Plot Results

# %%
plt.figure(figsize=(12, 8))
plt.step(labels.index[labels.index.year == 2018], labels[labels.index.year == 2018])
plt.step(labels.index[labels.index.year == 2018], y_pred);

# %% [markdown]
# ## Pearson Correlation

# %%
corr = np.corrcoef(data, rowvar=False)

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(corr, annot=True);

# %%
data.columns.values
